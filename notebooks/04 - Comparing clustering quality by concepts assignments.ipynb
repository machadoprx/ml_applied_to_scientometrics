# %%
import pandas as pd
from tqdm import tqdm
import networkx as nx
from bs4 import BeautifulSoup
import seaborn as sns
import numpy as np
import pickle as pkl
from typing import List
from collections import Counter
import torch
from torch_geometric.utils.convert import to_networkx, from_networkx
from networkx.algorithms.community.quality import modularity
from tqdm import tqdm
import gc; gc.enable();

# %% [markdown]
# * Given many graph clustering metrics and considering the current citation graph as ground truth, we will compare different communities partitioning,
# firstly considering keyword and concepts extraction methods.
# * OpenAlex keyword extraction uses https://github.com/ourresearch/openalex-keywords/tree/main/v1

# %%
df = pd.read_pickle("df_en_sorted_minimal.pkl")
edge_indices = torch.load("torch_geometric_ds.bin")

# %%
G_networkx = to_networkx(edge_indices)

# %%
gc.collect()
# Out:
# 0

# %%
open_alex_keyword_communities_first_kw = {}
#keys_dict = {}

for i, row in df.iterrows():
    ks = eval(row["keywords"])
    if len(ks) > 0:
        first_row_key = ks[0]
    else:
        first_row_key = "no_keyword_attributed"
    
    if first_row_key not in open_alex_keyword_communities_first_kw:
        open_alex_keyword_communities_first_kw[first_row_key] = {i}
    else:
        open_alex_keyword_communities_first_kw[first_row_key] = open_alex_keyword_communities_first_kw[first_row_key] | {i}

# %%
modularity(G_networkx, list(open_alex_keyword_communities_first_kw.values()), weight=None, resolution=1)
# Out:
# 0.024036344837202683

# %%
frozenset()
# Out:
# frozenset()

# %%
from itertools import chain, combinations

def powerset(iterable):
    s = list(iterable)
    return list(chain.from_iterable(combinations(s, r) for r in range(len(s)+1)))
    
def fill_tree(tree, sorted_keys, val):

    element = sorted_keys[0]
    if len(sorted_keys) == 1:
        if element in tree.keys():
            tree[element] = {
                "nodes": tree[element]["nodes"] | {val},
                "leafs": tree[element]["leafs"]
            }
        else:
            tree[element] = {
                "nodes": {val},
                "leafs": {}
            }
    else:    
        sorted_keys.pop(0)
        if element in tree:
            tree[element]["leafs"] = fill_tree(tree[element]["leafs"], sorted_keys, val)
        else:
            tree[element] = {
                "nodes": set(),
                "leafs": {}
            }
            tree[element]["leafs"] = fill_tree(tree[element]["leafs"], sorted_keys, val)
                
    return tree

# %%
def sum_tree_nodes(tree, visited=set()):
    
    for key in tree.keys():
        visited = visited | tree[key]["nodes"]
        visited = visited | sum_tree_nodes(tree[key]["leafs"], visited) 
    
    return visited

# %%
def reduce_tree(tree, target, visited=set()):

    for key in tree.keys():
        #if target.issubsetxx(key):
        if key in target:
            visited = visited | tree[key]["nodes"]
            visited = visited | sum_tree_nodes(tree[key]["leafs"], visited=visited)
        visited = visited | reduce_tree(tree[key]["leafs"], target, visited=visited)
    return visited

# %%
def partition_tree(tree, height=1, max_height=3):
    if len(tree["nodes"]) > 0:
        #partitions.append(tree["nodes"])
        yield tree["nodes"]
    
    for key in tree["leafs"].keys():
        if height + 1 == max_height:
            #print(tree["leafs"][key]["nodes"] | sum_tree_nodes(tree["leafs"][key]["leafs"], visited=set()))
            #partitions.append(tree["leafs"][key]["nodes"] | sum_tree_nodes(tree["leafs"][key]["leafs"], visited=set()))
            yield tree["leafs"][key]["nodes"] | sum_tree_nodes(tree["leafs"][key]["leafs"], visited=set())
        else:
            #partitions.append(partition_tree(tree["leafs"][key], height + 1, max_height=max_height))
            yield from partition_tree(tree["leafs"][key], height + 1, max_height=max_height)
    #return partitions

# %%
df_samp = df #.sample(n=10000).reset_index(drop=True)
nodes_keywords = []
threshold = 0.7
for i, kwd in tqdm(enumerate(df_samp["concepts"].tolist()), total=len(df_samp["concepts"])):
    kwd = [x[0] for x in eval(kwd) if x[1] >= threshold]#[:3]
    #kwd = frozenset(kwd)
    if len(kwd) == 0:
        nodes_keywords.append((i, ["no_keyword_attributed"], 1))
    else:
        nodes_keywords.append((i, kwd, len(kwd)))
#nodes_keywords = sorted(nodes_keywords, key=lambda x: x[2])
# Out:
# 100%|████████████████████| 2048707/2048707 [02:13<00:00, 15351.46it/s]

# %%
tree = {}
for nodes_info in tqdm(nodes_keywords, total=len(nodes_keywords)):
    node_idx, node_keys, _ = nodes_info
    #if node_keys not in tree:
    #    tree[frozenset()]
    tree = fill_tree(tree, node_keys, node_idx)
# Out:
#  71%|███████████████▌      | 1450267/2048707 [16:32<11:04, 901.03it/s]

# %%
import json
#pkl.dump(tree, open(f"trie_threshold_{int(100 * threshold)}.pkl", "wb"))

# %%
gen = partition_tree(tree["Graphene"], height=0, max_height=2)

# %%
all = []
for obj in gen:
    all.append(obj)

# %%
partitions = []
for k in tree.keys():
    #gen = partition_tree(tree[k], height=0, max_height=1)
    #for obj in gen:
    #    partitions.append(obj)
    partitions.append(tree[k]["nodes"] | sum_tree_nodes(tree[k]["leafs"], visited=set()))

# %%
modularity(G_networkx, partitions, weight=None, resolution=0.01)

# %%
[len(x) for x in partitions]

# %%
tree["Graphene"]

# %%
tree["Graphene"]["leafs"]["Crystallite"]["leafs"]

# %%
df.iloc[398460]["concepts"]

# %%
#gen[1]

# %%
partitions = []
for obj in gen:
    partitions.append(obj)

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 next(gen)
#
# StopIteration:

# %%
partitions
# Out:
# []

# %%
len(sum_tree_nodes(tree[frozenset(["Graphene"])]["leafs"]))
# Out:
# 15015

# %%
tree["Graphene"].keys()
# Out:
# dict_keys(['nodes', 'leafs'])

# %%
#test_tree = tree[frozenset(['model'])] #["leafs"]
df.iloc[sorted(list(tree["Graphene"]["nodes"] | sum_tree_nodes(tree["Graphene"]["leafs"])))]
# Out:
#                                        id  \
# 239      https://openalex.org/W1018953785
# 267      https://openalex.org/W1021326259
# 413      https://openalex.org/W1031618044
# 604      https://openalex.org/W1048209023
# 608      https://openalex.org/W1048450219
# ...                                   ...
# 2048126   https://openalex.org/W957922153
# 2048128   https://openalex.org/W958056737
# 2048218   https://openalex.org/W965259619
# 2048525   https://openalex.org/W987021357
# 2048691   https://openalex.org/W998504095
#
#                                                   abstract  \
# 239      we show that graphene single crystals as large...
# 267      we theoretically study the influence of surfac...
# 413      the telescopic contact between graphene layers...
# 604      graphene is a promising material for high-perf...
# 608      graphene, a single atomic layer of graphite, h...
# ...                                                    ...
# 2048126  carrier mobility and chemical doping level are...
# 2048128  graphene is a semimetal with zero band gap, wh...
# 2048218  intrinsic localized modes or discrete breather...
# 2048525  stacking graphene sheets forms graphite. two i...
# 2048691  owing to its relativistic low-energy charge ca...
#
#                                                      title publication_date  \
# 239      chemical vapor deposition growth of 5 mm hexag...       2015-11-01
# 267      surface optical phonon-assisted cyclotron reso...       2015-08-01
# 413      tunneling conductance of telescopic contacts b...       2015-11-01
# 604      synthesis, charge transport and device applica...       2015-12-01
# 608      growth morphology and properties of metals on ...       2015-12-01
# ...                                                    ...              ...
# 2048126                          graphene mobility mapping       2015-07-24
# 2048128  semiconducting graphene on silicon from first-...       2015-08-10
# 2048218  long-lived discrete breathers in free-standing...       2016-06-01
# 2048525  graphite under uniaxial compression along thec...       2015-09-22
# 2048691  fabrication of gate-tunable graphene devices f...       2015-07-24
#
#                                                   keywords  \
# 239              ['graphene', 'ethanol', 'single-crystal']
# 267      ['graphene', 'cyclotron resonance', 'optical',...
# 413      ['graphene layers', 'tunneling conductance', '...
# 604                     ['graphene nanoribbons', 'charge']
# 608                       ['graphene', 'metals', 'growth']
# ...                                                    ...
# 2048126                      ['graphene mobility mapping']
# 2048128  ['graphene', 'semiconducting', 'silicon', 'fir...
# 2048218  ['discrete breathers', 'long-lived', 'free-sta...
# 2048525  ['graphite', 'uniaxial compression', 'strain',...
# 2048691  ['graphene', 'scanning tunneling microscopy st...
#
#                                                   concepts
# 239      [('Graphene', 0.8950863), ('Chemical vapor dep...
# 267      [('Graphene', 0.9213928), ('Materials science'...
# 413      [('Graphene', 0.8410138), ('Quantum tunnelling...
# 604      [('Graphene', 0.85890615), ('Graphene nanoribb...
# 608      [('Graphene', 0.9511391), ('Materials science'...
# ...                                                    ...
# 2048126  [('Graphene', 0.94014764), ('Materials science...
# 2048128  [('Graphene', 0.9208318), ('Bilayer graphene',...
# 2048218  [('Graphene', 0.90510213), ('Breather', 0.8442...
# 2048525  [('Graphene', 0.747055), ('Graphite', 0.658367...
# 2048691  [('Graphene', 0.9637902), ('Scanning tunneling...
#
# [7891 rows x 6 columns]

# %%
idx = sorted(list(reduce_tree(tree, ["Graphene"], visited=set())))
df.iloc[idx]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 idx = sorted(list(reduce_tree(tree, ["Graphene"], visited=set())))
#       2 df.iloc[idx]
#
# Cell In[20], line 11, in reduce_tree(tree, target, visited)
#       9         visited = visited | tree[key]["nodes"]
#      10         visited = visited | sum_tree_nodes(tree[key]["leafs"], visited=visited)
# ---> 11     visited = visited | reduce_tree(tree[key]["leafs"], target, visited=visited)
#      12 return visited
#
# Cell In[20], line 11, in reduce_tree(tree, target, visited)
#       9         visited = visited | tree[key]["nodes"]
#      10         visited = visited | sum_tree_nodes(tree[key]["leafs"], visited=visited)
# ---> 11     visited = visited | reduce_tree(tree[key]["leafs"], target, visited=visited)
#      12 return visited
#
#     [... skipping similar frames: reduce_tree at line 11 (1 times)]
#
# Cell In[20], line 11, in reduce_tree(tree, target, visited)
#       9         visited = visited | tree[key]["nodes"]
#      10         visited = visited | sum_tree_nodes(tree[key]["leafs"], visited=visited)
# ---> 11     visited = visited | reduce_tree(tree[key]["leafs"], target, visited=visited)
#      12 return visited
#
# KeyboardInterrupt:

# %%
idx = sorted(list(sum_tree_nodes(tree["Graphene"]["leafs"], visited=set())))
df.iloc[idx]
# Out:
#                                        id  \
# 239      https://openalex.org/W1018953785
# 267      https://openalex.org/W1021326259
# 413      https://openalex.org/W1031618044
# 604      https://openalex.org/W1048209023
# 608      https://openalex.org/W1048450219
# ...                                   ...
# 2048126   https://openalex.org/W957922153
# 2048128   https://openalex.org/W958056737
# 2048218   https://openalex.org/W965259619
# 2048525   https://openalex.org/W987021357
# 2048691   https://openalex.org/W998504095
#
#                                                   abstract  \
# 239      we show that graphene single crystals as large...
# 267      we theoretically study the influence of surfac...
# 413      the telescopic contact between graphene layers...
# 604      graphene is a promising material for high-perf...
# 608      graphene, a single atomic layer of graphite, h...
# ...                                                    ...
# 2048126  carrier mobility and chemical doping level are...
# 2048128  graphene is a semimetal with zero band gap, wh...
# 2048218  intrinsic localized modes or discrete breather...
# 2048525  stacking graphene sheets forms graphite. two i...
# 2048691  owing to its relativistic low-energy charge ca...
#
#                                                      title publication_date  \
# 239      chemical vapor deposition growth of 5 mm hexag...       2015-11-01
# 267      surface optical phonon-assisted cyclotron reso...       2015-08-01
# 413      tunneling conductance of telescopic contacts b...       2015-11-01
# 604      synthesis, charge transport and device applica...       2015-12-01
# 608      growth morphology and properties of metals on ...       2015-12-01
# ...                                                    ...              ...
# 2048126                          graphene mobility mapping       2015-07-24
# 2048128  semiconducting graphene on silicon from first-...       2015-08-10
# 2048218  long-lived discrete breathers in free-standing...       2016-06-01
# 2048525  graphite under uniaxial compression along thec...       2015-09-22
# 2048691  fabrication of gate-tunable graphene devices f...       2015-07-24
#
#                                                   keywords  \
# 239              ['graphene', 'ethanol', 'single-crystal']
# 267      ['graphene', 'cyclotron resonance', 'optical',...
# 413      ['graphene layers', 'tunneling conductance', '...
# 604                     ['graphene nanoribbons', 'charge']
# 608                       ['graphene', 'metals', 'growth']
# ...                                                    ...
# 2048126                      ['graphene mobility mapping']
# 2048128  ['graphene', 'semiconducting', 'silicon', 'fir...
# 2048218  ['discrete breathers', 'long-lived', 'free-sta...
# 2048525  ['graphite', 'uniaxial compression', 'strain',...
# 2048691  ['graphene', 'scanning tunneling microscopy st...
#
#                                                   concepts
# 239      [('Graphene', 0.8950863), ('Chemical vapor dep...
# 267      [('Graphene', 0.9213928), ('Materials science'...
# 413      [('Graphene', 0.8410138), ('Quantum tunnelling...
# 604      [('Graphene', 0.85890615), ('Graphene nanoribb...
# 608      [('Graphene', 0.9511391), ('Materials science'...
# ...                                                    ...
# 2048126  [('Graphene', 0.94014764), ('Materials science...
# 2048128  [('Graphene', 0.9208318), ('Bilayer graphene',...
# 2048218  [('Graphene', 0.90510213), ('Breather', 0.8442...
# 2048525  [('Graphene', 0.747055), ('Graphite', 0.658367...
# 2048691  [('Graphene', 0.9637902), ('Scanning tunneling...
#
# [8117 rows x 6 columns]

# %%
# normal

# %%
nodes_concepts = [list([c[0] for c in eval(x)[:5]]) for x in df["concepts"].tolist()]

# %%
df[list(map(lambda x: list(x)[0] == "Graphene", nodes_concepts))]
# Out:
#                                        id  \
# 239      https://openalex.org/W1018953785
# 267      https://openalex.org/W1021326259
# 413      https://openalex.org/W1031618044
# 604      https://openalex.org/W1048209023
# 608      https://openalex.org/W1048450219
# ...                                   ...
# 2048126   https://openalex.org/W957922153
# 2048128   https://openalex.org/W958056737
# 2048218   https://openalex.org/W965259619
# 2048525   https://openalex.org/W987021357
# 2048691   https://openalex.org/W998504095
#
#                                                   abstract  \
# 239      we show that graphene single crystals as large...
# 267      we theoretically study the influence of surfac...
# 413      the telescopic contact between graphene layers...
# 604      graphene is a promising material for high-perf...
# 608      graphene, a single atomic layer of graphite, h...
# ...                                                    ...
# 2048126  carrier mobility and chemical doping level are...
# 2048128  graphene is a semimetal with zero band gap, wh...
# 2048218  intrinsic localized modes or discrete breather...
# 2048525  stacking graphene sheets forms graphite. two i...
# 2048691  owing to its relativistic low-energy charge ca...
#
#                                                      title publication_date  \
# 239      chemical vapor deposition growth of 5 mm hexag...       2015-11-01
# 267      surface optical phonon-assisted cyclotron reso...       2015-08-01
# 413      tunneling conductance of telescopic contacts b...       2015-11-01
# 604      synthesis, charge transport and device applica...       2015-12-01
# 608      growth morphology and properties of metals on ...       2015-12-01
# ...                                                    ...              ...
# 2048126                          graphene mobility mapping       2015-07-24
# 2048128  semiconducting graphene on silicon from first-...       2015-08-10
# 2048218  long-lived discrete breathers in free-standing...       2016-06-01
# 2048525  graphite under uniaxial compression along thec...       2015-09-22
# 2048691  fabrication of gate-tunable graphene devices f...       2015-07-24
#
#                                                   keywords  \
# 239              ['graphene', 'ethanol', 'single-crystal']
# 267      ['graphene', 'cyclotron resonance', 'optical',...
# 413      ['graphene layers', 'tunneling conductance', '...
# 604                     ['graphene nanoribbons', 'charge']
# 608                       ['graphene', 'metals', 'growth']
# ...                                                    ...
# 2048126                      ['graphene mobility mapping']
# 2048128  ['graphene', 'semiconducting', 'silicon', 'fir...
# 2048218  ['discrete breathers', 'long-lived', 'free-sta...
# 2048525  ['graphite', 'uniaxial compression', 'strain',...
# 2048691  ['graphene', 'scanning tunneling microscopy st...
#
#                                                   concepts
# 239      [('Graphene', 0.8950863), ('Chemical vapor dep...
# 267      [('Graphene', 0.9213928), ('Materials science'...
# 413      [('Graphene', 0.8410138), ('Quantum tunnelling...
# 604      [('Graphene', 0.85890615), ('Graphene nanoribb...
# 608      [('Graphene', 0.9511391), ('Materials science'...
# ...                                                    ...
# 2048126  [('Graphene', 0.94014764), ('Materials science...
# 2048128  [('Graphene', 0.9208318), ('Bilayer graphene',...
# 2048218  [('Graphene', 0.90510213), ('Breather', 0.8442...
# 2048525  [('Graphene', 0.747055), ('Graphite', 0.658367...
# 2048691  [('Graphene', 0.9637902), ('Scanning tunneling...
#
# [8117 rows x 6 columns]

# %%
tree["Superconductivity"]
# Out:
# {'nodes': set(),
#  'leafs': {'Pairing': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {84,
#       9882,
#       24210,
#       36448,
#       60407,
#       81717,
#       101188,
#       107409,
#       146889,
#       186471,
#       190047,
#       197240,
#       208518,
#       235224,
#       236147,
#       283450,
#       315021,
#       350360,
#       365299,
#       386555,
#       397272,
#       414573,
#       428601,
#       442278,
#       450251,
#       535690,
#       567112,
#       624503,
#       709425,
#       727307,
#       778850,
#       793793,
#       796546,
#       799436,
#       829488,
#       854986,
#       867562,
#       878194,
#       883509,
#       923481,
#       961708,
#       1030931,
#       1039981,
#       1044112,
#       1089351,
#       1144365,
#       1153481,
#       1188070,
#       1210224,
#       1228060,
#       1240076,
#       1277000,
#       1306953,
#       1312159,
#       1319961,
#       1365759,
#       1426874,
#       1445213,
#       1451173,
#       1554178,
#       1559446,
#       1580920,
#       1598038,
#       1603754,
#       1621680,
#       1630746,
#       1639828,
#       1656810,
#       1659652,
#       1662203,
#       1673021,
#       1684080,
#       1710929,
#       1724549,
#       1728903,
#       1758722,
#       1812571,
#       1813839,
#       1817445,
#       1820718,
#       1832089,
#       1839106,
#       1873790,
#       1876422,
#       1885343,
#       1933785,
#       1957023,
#       1972722,
#       1974173,
#       1994700,
#       2001270,
#       2015077,
#       2020574},
#      'leafs': {}},
#     'Hamiltonian (control theory)': {'nodes': {6412, 1706795}, 'leafs': {}},
#     'Physics': {'nodes': {13949,
#       28165,
#       39951,
#       42729,
#       254032,
#       348101,
#       386519,
#       441715,
#       465234,
#       489585,
#       498528,
#       503722,
#       553082,
#       769410,
#       796274,
#       811253,
#       889184,
#       915691,
#       1017649,
#       1232039,
#       1256700,
#       1369146,
#       1392850,
#       1422924,
#       1454541,
#       1490228,
#       1563036,
#       1582337,
#       1600191,
#       1614919,
#       1644893,
#       1670810,
#       1674115,
#       1727482,
#       1729066,
#       1764761,
#       1778883,
#       1800396,
#       1817595,
#       1837777,
#       1867945,
#       1891230,
#       1916559,
#       1942789,
#       2024071},
#      'leafs': {}},
#     'Pnictogen': {'nodes': {14832}, 'leafs': {}},
#     'Monolayer': {'nodes': {27735}, 'leafs': {}},
#     'Phonon': {'nodes': {28763, 1706809}, 'leafs': {}},
#     'Hubbard model': {'nodes': {75697, 1808894}, 'leafs': {}},
#     'Superfluidity': {'nodes': {166402, 760604}, 'leafs': {}},
#     'Ferromagnetism': {'nodes': {334969, 485985, 1661617}, 'leafs': {}},
#     'Scattering': {'nodes': {354743}, 'leafs': {}},
#     'Heat capacity': {'nodes': {405865}, 'leafs': {}},
#     'Raman spectroscopy': {'nodes': {430500, 637944, 1525263}, 'leafs': {}},
#     'Vortex': {'nodes': {444563}, 'leafs': {}},
#     'Fermi surface': {'nodes': {458499, 1121534, 1876870}, 'leafs': {}},
#     'Antiferromagnetism': {'nodes': {521667,
#       973002,
#       1084507,
#       1319041,
#       2000878},
#      'leafs': {}},
#     'Character (mathematics)': {'nodes': {582769}, 'leafs': {}},
#     'BCS theory': {'nodes': {606628}, 'leafs': {}},
#     'Coulomb': {'nodes': {613391}, 'leafs': {}},
#     'Knight shift': {'nodes': {658933, 755640}, 'leafs': {}},
#     'Phase diagram': {'nodes': {706260}, 'leafs': {}},
#     'Electron': {'nodes': {726173, 1020119, 1681102}, 'leafs': {}},
#     'Inelastic neutron scattering': {'nodes': {727944}, 'leafs': {}},
#     'Analogy': {'nodes': {794790}, 'leafs': {}},
#     'Cuprate': {'nodes': {864785,
#       901135,
#       1126309,
#       1141042,
#       1632494,
#       1752789,
#       1963396},
#      'leafs': {}},
#     'Mesoscopic physics': {'nodes': {927121}, 'leafs': {}},
#     'Specific heat': {'nodes': {980706}, 'leafs': {}},
#     'Conductance': {'nodes': {986441}, 'leafs': {}},
#     'Isostructural': {'nodes': {1015813}, 'leafs': {}},
#     'Quasiparticle': {'nodes': {1084430, 1965672}, 'leafs': {}},
#     'Impurity': {'nodes': {1109179}, 'leafs': {}},
#     'Symmetry (geometry)': {'nodes': {1112216}, 'leafs': {}},
#     'Formalism (music)': {'nodes': {1145270, 1847793}, 'leafs': {}},
#     'Magnetism': {'nodes': {1201200, 1916963, 1940867}, 'leafs': {}},
#     'Proximity effect (electron beam lithography)': {'nodes': {1204990},
#      'leafs': {}},
#     'Anisotropy': {'nodes': {1292358, 1839465}, 'leafs': {}},
#     'Context (archaeology)': {'nodes': {1376548}, 'leafs': {}},
#     'Current (fluid)': {'nodes': {1394183}, 'leafs': {}},
#     'Coupling (piping)': {'nodes': {1625146}, 'leafs': {}},
#     'Instability': {'nodes': {1640090}, 'leafs': {}},
#     'Heavy fermion': {'nodes': {1691080}, 'leafs': {}},
#     'Topological insulator': {'nodes': {1791142}, 'leafs': {}},
#     'Chalcogenide': {'nodes': {1806357}, 'leafs': {}},
#     'Topology (electrical circuits)': {'nodes': {1833415}, 'leafs': {}},
#     'Muon spin spectroscopy': {'nodes': {1839282}, 'leafs': {}},
#     'London penetration depth': {'nodes': {1887572}, 'leafs': {}},
#     'Cooper pair': {'nodes': {1892580}, 'leafs': {}},
#     'Photoemission spectroscopy': {'nodes': {1939830}, 'leafs': {}},
#     'Graphene': {'nodes': {1975028}, 'leafs': {}},
#     'Scanning tunneling microscope': {'nodes': {2013268}, 'leafs': {}},
#     'Intermetallic': {'nodes': {2025634}, 'leafs': {}}}},
#   'Physics': {'nodes': set(),
#    'leafs': {'Alkali metal': {'nodes': {246, 45440}, 'leafs': {}},
#     'Critical field': {'nodes': {329,
#       56425,
#       63253,
#       281983,
#       472545,
#       591944,
#       752217,
#       1063708,
#       1772190,
#       2045013},
#      'leafs': {}},
#     'Impurity': {'nodes': {519, 67987, 1179949}, 'leafs': {}},
#     'Condensed matter physics': {'nodes': {569,
#       1893,
#       3250,
#       6812,
#       8399,
#       8774,
#       12527,
#       13906,
#       14723,
#       19006,
#       19715,
#       19940,
#       20210,
#       22482,
#       24793,
#       25368,
#       28345,
#       28646,
#       30189,
#       32537,
#       32728,
#       34495,
#       37247,
#       38838,
#       39148,
#       39437,
#       39542,
#       41591,
#       41941,
#       41980,
#       42071,
#       42874,
#       43095,
#       43615,
#       43642,
#       44204,
#       45611,
#       45966,
#       46317,
#       47020,
#       47836,
#       47945,
#       48304,
#       48889,
#       49951,
#       50372,
#       51682,
#       52970,
#       53357,
#       53788,
#       53792,
#       54624,
#       54833,
#       55354,
#       55895,
#       55966,
#       56378,
#       57650,
#       57923,
#       61743,
#       61861,
#       63605,
#       65665,
#       68328,
#       72014,
#       72727,
#       73541,
#       75091,
#       77943,
#       82017,
#       82090,
#       82236,
#       83156,
#       91764,
#       93002,
#       93929,
#       104103,
#       107138,
#       108430,
#       110720,
#       115264,
#       118009,
#       118462,
#       122268,
#       130118,
#       136874,
#       136945,
#       138467,
#       141796,
#       142154,
#       143850,
#       152424,
#       161241,
#       165723,
#       167671,
#       168025,
#       168953,
#       192676,
#       204019,
#       208599,
#       213441,
#       216045,
#       222037,
#       222538,
#       224328,
#       225838,
#       227963,
#       228558,
#       238173,
#       240093,
#       245000,
#       246955,
#       247765,
#       247780,
#       254768,
#       257956,
#       262075,
#       263413,
#       266534,
#       266792,
#       275793,
#       283034,
#       289114,
#       290662,
#       291050,
#       292123,
#       300048,
#       307186,
#       308802,
#       312882,
#       314615,
#       319463,
#       320611,
#       322445,
#       325764,
#       338246,
#       339382,
#       340581,
#       346608,
#       347231,
#       347696,
#       356912,
#       365506,
#       366831,
#       369185,
#       369574,
#       370322,
#       380570,
#       382706,
#       385452,
#       388808,
#       390003,
#       391503,
#       394102,
#       395207,
#       399768,
#       407124,
#       408032,
#       413265,
#       414153,
#       417326,
#       422092,
#       422233,
#       426437,
#       427029,
#       429425,
#       434188,
#       439044,
#       446796,
#       454618,
#       459764,
#       470477,
#       476014,
#       476393,
#       477432,
#       477545,
#       478652,
#       488592,
#       495970,
#       498319,
#       499915,
#       500328,
#       502476,
#       504926,
#       505734,
#       506954,
#       509783,
#       515320,
#       515598,
#       525473,
#       531986,
#       540244,
#       565128,
#       568530,
#       569758,
#       576054,
#       587958,
#       591118,
#       602991,
#       603631,
#       612255,
#       613938,
#       626999,
#       631122,
#       641676,
#       644252,
#       650344,
#       655091,
#       656922,
#       662201,
#       662264,
#       672056,
#       677300,
#       684483,
#       687137,
#       688864,
#       693800,
#       696832,
#       698961,
#       700728,
#       701760,
#       705410,
#       705533,
#       706699,
#       714066,
#       718331,
#       718943,
#       721507,
#       722172,
#       723129,
#       730562,
#       732309,
#       734235,
#       747292,
#       755843,
#       774028,
#       780762,
#       792825,
#       793344,
#       794745,
#       796136,
#       804729,
#       809536,
#       811585,
#       813660,
#       817065,
#       818287,
#       823538,
#       851160,
#       851869,
#       866930,
#       870458,
#       872076,
#       873181,
#       875673,
#       878365,
#       878886,
#       879863,
#       885498,
#       886660,
#       887372,
#       891587,
#       893441,
#       894427,
#       897229,
#       908742,
#       909254,
#       911446,
#       918341,
#       919981,
#       922436,
#       935633,
#       939264,
#       949037,
#       951091,
#       953684,
#       954074,
#       955898,
#       960924,
#       961099,
#       962023,
#       969462,
#       969947,
#       971710,
#       972277,
#       978929,
#       983703,
#       991181,
#       993536,
#       996706,
#       997203,
#       998053,
#       998325,
#       1000093,
#       1001686,
#       1004535,
#       1005378,
#       1006393,
#       1008125,
#       1010784,
#       1013571,
#       1021246,
#       1024399,
#       1031882,
#       1033541,
#       1037553,
#       1043772,
#       1047340,
#       1050315,
#       1055979,
#       1057035,
#       1067460,
#       1069891,
#       1074234,
#       1090432,
#       1091126,
#       1091524,
#       1092478,
#       1094494,
#       1095106,
#       1097667,
#       1098906,
#       1101477,
#       1103391,
#       1103575,
#       1106441,
#       1119349,
#       1119415,
#       1124972,
#       1125989,
#       1127441,
#       1127683,
#       1127691,
#       1128671,
#       1130451,
#       1131463,
#       1141232,
#       1143230,
#       1154098,
#       1154101,
#       1159779,
#       1180024,
#       1181146,
#       1182209,
#       1192072,
#       1207369,
#       1210781,
#       1225630,
#       1226395,
#       1231671,
#       1232920,
#       1238652,
#       1238952,
#       1239056,
#       1240561,
#       1241449,
#       1248028,
#       1251256,
#       1253964,
#       1257095,
#       1259166,
#       1265312,
#       1268190,
#       1276671,
#       1278509,
#       1281363,
#       1282648,
#       1285499,
#       1289258,
#       1290304,
#       1301302,
#       1301303,
#       1304619,
#       1307578,
#       1315768,
#       1317124,
#       1318508,
#       1323470,
#       1326472,
#       1335083,
#       1346327,
#       1351362,
#       1363946,
#       1363971,
#       1368319,
#       1380290,
#       1386604,
#       1386852,
#       1391079,
#       1400309,
#       1401319,
#       1402054,
#       1411771,
#       1417020,
#       1442157,
#       1448219,
#       1451331,
#       1452552,
#       1454555,
#       1459913,
#       1467056,
#       1468171,
#       1468343,
#       1473721,
#       1485916,
#       1507338,
#       1508658,
#       1514422,
#       1517379,
#       1517480,
#       1539957,
#       1549413,
#       1557946,
#       1559341,
#       1569887,
#       1570662,
#       1573136,
#       1574873,
#       1580266,
#       1586536,
#       1586673,
#       1597631,
#       1602921,
#       1607120,
#       1611095,
#       1611901,
#       1631558,
#       1636801,
#       1637655,
#       1637867,
#       1640187,
#       1652530,
#       1654193,
#       1655589,
#       1658163,
#       1658414,
#       1666670,
#       1672705,
#       1673600,
#       1675810,
#       1679817,
#       1685468,
#       1687102,
#       1695696,
#       1695784,
#       1699625,
#       1705029,
#       1705610,
#       1706320,
#       1707076,
#       1709543,
#       1710173,
#       1713874,
#       1717327,
#       1721388,
#       1723781,
#       1724277,
#       1724641,
#       1728063,
#       1729144,
#       1729204,
#       1733281,
#       1735764,
#       1744372,
#       1752837,
#       1753203,
#       1754099,
#       1764447,
#       1767025,
#       1767487,
#       1767830,
#       1768793,
#       1771253,
#       1773325,
#       1778113,
#       1779610,
#       1786850,
#       1787236,
#       1790497,
#       1791694,
#       1792024,
#       1792111,
#       1796718,
#       1798044,
#       1798399,
#       1802918,
#       1803300,
#       1804260,
#       1806257,
#       1808809,
#       1813429,
#       1814856,
#       1815919,
#       1816016,
#       1818224,
#       1823640,
#       1825027,
#       1827960,
#       1828782,
#       1828986,
#       1832924,
#       1837480,
#       1839781,
#       1841534,
#       1841872,
#       1842767,
#       1844633,
#       1848706,
#       1850092,
#       1850250,
#       1850466,
#       1853872,
#       1863325,
#       1865671,
#       1866776,
#       1867230,
#       1869560,
#       1873204,
#       1873993,
#       1882243,
#       1882616,
#       1883461,
#       1884276,
#       1888140,
#       1890514,
#       1895223,
#       1897947,
#       1900096,
#       1903197,
#       1903233,
#       1905035,
#       1906610,
#       1909583,
#       1914681,
#       1915250,
#       1917274,
#       1917567,
#       1918955,
#       1920216,
#       1927886,
#       1931574,
#       1932458,
#       1942899,
#       1944050,
#       1944079,
#       1945358,
#       1949618,
#       1950739,
#       1954078,
#       1954412,
#       1955236,
#       1956607,
#       1957811,
#       1966167,
#       1967232,
#       1968914,
#       1972046,
#       1990995,
#       2005615,
#       2009695,
#       2009933,
#       2013123,
#       2013378,
#       2014581,
#       2018304,
#       2022209,
#       2022887,
#       2024061,
#       2025544,
#       2026063,
#       2027980,
#       2035880,
#       2043967,
#       2046939},
#      'leafs': {}},
#     'Metastability': {'nodes': {759, 492775}, 'leafs': {}},
#     'Hubbard model': {'nodes': {848, 82903, 208569, 670457, 914017, 1882850},
#      'leafs': {}},
#     'Order (exchange)': {'nodes': {1174,
#       15395,
#       185207,
#       283130,
#       303728,
#       407224,
#       408458,
#       486616,
#       786541,
#       909367,
#       934342,
#       1111127,
#       1125618,
#       1208953,
#       1250599,
#       1285344,
#       1561548,
#       1608194,
#       1677600,
#       1677971,
#       1678919,
#       1715278,
#       1787422,
#       1848421,
#       1975208,
#       2044115},
#      'leafs': {}},
#     'Moment of inertia': {'nodes': {4083}, 'leafs': {}},
#     'Magnetic moment': {'nodes': {9757, 290601}, 'leafs': {}},
#     'Metal': {'nodes': {9849, 1326614}, 'leafs': {}},
#     'Lasing threshold': {'nodes': {12096}, 'leafs': {}},
#     'Pairing': {'nodes': {13781,
#       23956,
#       27083,
#       27972,
#       39949,
#       52918,
#       53412,
#       66176,
#       81461,
#       110089,
#       163446,
#       235366,
#       284100,
#       478534,
#       569865,
#       586976,
#       869401,
#       954140,
#       962963,
#       1135470,
#       1141915,
#       1182232,
#       1252375,
#       1291023,
#       1303959,
#       1404928,
#       1575636,
#       1626935,
#       1643584,
#       1654784,
#       1813580,
#       1853592,
#       1904014,
#       1905113,
#       1920792,
#       2037625},
#      'leafs': {}},
#     'Boson': {'nodes': {14095, 131624, 404293}, 'leafs': {}},
#     'Quasiparticle': {'nodes': {14630,
#       27515,
#       446414,
#       802233,
#       840072,
#       1016464,
#       1146146,
#       1352013,
#       1361075,
#       1367966,
#       1671473,
#       1912449},
#      'leafs': {}},
#     'Residual resistivity': {'nodes': {15358}, 'leafs': {}},
#     'Coherence length': {'nodes': {15423, 338527, 839300, 993287, 1828607},
#      'leafs': {}},
#     'Bound state': {'nodes': {16660, 51247, 1341967, 2025330}, 'leafs': {}},
#     'Ferromagnetism': {'nodes': {16835, 792785, 1660470, 1879043},
#      'leafs': {}},
#     'Lambda': {'nodes': {17137,
#       94796,
#       252457,
#       618341,
#       792292,
#       819309,
#       973351,
#       1025084,
#       1051825,
#       1663685,
#       1745387},
#      'leafs': {}},
#     'Context (archaeology)': {'nodes': {17432}, 'leafs': {}},
#     'Niobium': {'nodes': {21413}, 'leafs': {}},
#     'Fermion': {'nodes': {22433,
#       186810,
#       1354999,
#       1527088,
#       1722001,
#       1742878,
#       1818110},
#      'leafs': {}},
#     'Zeeman effect': {'nodes': {22753, 1648361, 1729004}, 'leafs': {}},
#     'Field (mathematics)': {'nodes': {24345, 771630, 1067479, 1644451},
#      'leafs': {}},
#     'Quantum tunnelling': {'nodes': {28336,
#       937313,
#       958585,
#       984167,
#       1387358,
#       1708838},
#      'leafs': {}},
#     'Meissner effect': {'nodes': {28868, 49693, 431685, 1493737, 1710362},
#      'leafs': {}},
#     'Conductance': {'nodes': {30379, 33472}, 'leafs': {}},
#     'Coupling (piping)': {'nodes': {30455,
#       44320,
#       117362,
#       194157,
#       477724,
#       486704,
#       981956,
#       1092879,
#       1112650,
#       1309047,
#       1350440,
#       1389324,
#       1635183,
#       1837195,
#       1844893},
#      'leafs': {}},
#     'Diamagnetism': {'nodes': {31678,
#       35277,
#       654318,
#       672470,
#       958839,
#       1115362,
#       1211303,
#       1265188,
#       1612411},
#      'leafs': {}},
#     'High resolution': {'nodes': {31990}, 'leafs': {}},
#     'Crystallography': {'nodes': {32575,
#       34717,
#       40060,
#       47407,
#       56241,
#       211094,
#       252282,
#       271059,
#       454776,
#       488399,
#       800713,
#       884678,
#       1133314,
#       1282936,
#       1288694,
#       1661318,
#       1745464,
#       1778701,
#       1841881,
#       2016330,
#       2043311},
#      'leafs': {}},
#     'Paramagnetism': {'nodes': {33456, 1386260, 1853424}, 'leafs': {}},
#     'Local density of states': {'nodes': {33862}, 'leafs': {}},
#     'Hydrostatic equilibrium': {'nodes': {33899}, 'leafs': {}},
#     'Propagator': {'nodes': {35230}, 'leafs': {}},
#     'Lattice (music)': {'nodes': {36162,
#       48888,
#       53964,
#       745959,
#       787518,
#       876801,
#       1298102,
#       1481054,
#       2042964},
#      'leafs': {}},
#     'Materials science': {'nodes': {38236,
#       61784,
#       145055,
#       351454,
#       873255,
#       1333213,
#       1744986,
#       2044634},
#      'leafs': {}},
#     'Hall effect': {'nodes': {39525, 675590}, 'leafs': {}},
#     'Antiferromagnetism': {'nodes': {39577,
#       93913,
#       376304,
#       935753,
#       1155912,
#       1669228,
#       1710970,
#       1838936,
#       1909706},
#      'leafs': {}},
#     'Inelastic neutron scattering': {'nodes': {39895,
#       249140,
#       497961,
#       580488,
#       2036714},
#      'leafs': {}},
#     'Fermi level': {'nodes': {40765, 1802961}, 'leafs': {}},
#     'Orthorhombic crystal system': {'nodes': {41539, 274054, 803700, 1798263},
#      'leafs': {}},
#     'Cuprate': {'nodes': {41684,
#       62807,
#       197002,
#       257562,
#       460169,
#       464673,
#       490865,
#       574171,
#       756429,
#       784632,
#       816277,
#       898595,
#       985266,
#       1118166,
#       1308351,
#       1344842,
#       1394103,
#       1433424,
#       1974733,
#       1990989},
#      'leafs': {}},
#     'Energy (signal processing)': {'nodes': {42471,
#       50675,
#       52751,
#       55514,
#       57505,
#       143226,
#       374806,
#       608779,
#       740561,
#       891647,
#       1032582,
#       1188637,
#       1314266,
#       1319510,
#       1357687,
#       1472888,
#       1646314,
#       1826155,
#       1910265},
#      'leafs': {}},
#     'Tetragonal crystal system': {'nodes': {42474, 198432, 1649138},
#      'leafs': {}},
#     'Omega': {'nodes': {42628, 96532, 234850, 426070, 1431742}, 'leafs': {}},
#     'Electron': {'nodes': {43650,
#       114874,
#       133947,
#       425548,
#       732903,
#       762114,
#       1130471,
#       1151186,
#       1562279,
#       1577906,
#       1625230,
#       1807285,
#       1897115,
#       2035098},
#      'leafs': {}},
#     'Spectral line': {'nodes': {43738,
#       46481,
#       600918,
#       720321,
#       1078242,
#       2043214},
#      'leafs': {}},
#     'Phonon': {'nodes': {45104,
#       53530,
#       494336,
#       541810,
#       645651,
#       699169,
#       780919,
#       1062459,
#       1089921,
#       1130329,
#       1233105,
#       1284147,
#       1305659,
#       1359962,
#       1394250,
#       1566058,
#       1636248,
#       1675963,
#       1905045,
#       1906502,
#       2023454},
#      'leafs': {}},
#     'Coulomb': {'nodes': {45126, 241433, 726482, 1466095, 1653997, 1717425},
#      'leafs': {}},
#     'Scattering': {'nodes': {45965,
#       387072,
#       646158,
#       689789,
#       1032394,
#       1074825,
#       1757004,
#       1881556},
#      'leafs': {}},
#     'Delocalized electron': {'nodes': {46784}, 'leafs': {}},
#     'Lattice constant': {'nodes': {48331, 53080}, 'leafs': {}},
#     'Specific heat': {'nodes': {48426,
#       259373,
#       603250,
#       769700,
#       1060964,
#       1071499,
#       1237289,
#       1869302,
#       1888710,
#       1905727},
#      'leafs': {}},
#     'Content (measure theory)': {'nodes': {48494, 2048473}, 'leafs': {}},
#     'XANES': {'nodes': {51275}, 'leafs': {}},
#     'Phase (matter)': {'nodes': {51806, 486082, 834525, 840679}, 'leafs': {}},
#     'Flux (metallurgy)': {'nodes': {53362, 298610, 1087971, 1730240, 1794946},
#      'leafs': {}},
#     'Organic superconductor': {'nodes': {53683, 1235487, 1870617},
#      'leafs': {}},
#     'Excitation': {'nodes': {54752, 598738}, 'leafs': {}},
#     'Doping': {'nodes': {56363,
#       759801,
#       907265,
#       1036863,
#       1613285,
#       1746860,
#       2028263},
#      'leafs': {}},
#     'Anisotropy': {'nodes': {56958,
#       65624,
#       74763,
#       115247,
#       191327,
#       372784,
#       415524,
#       568476,
#       702883,
#       937892,
#       1065974,
#       1143418,
#       1254244,
#       1320238,
#       1783987,
#       1891769,
#       2027262},
#      'leafs': {}},
#     'Electrical resistivity and conductivity': {'nodes': {58297,
#       68972,
#       254993,
#       449754,
#       585145,
#       590144,
#       840735,
#       1051613,
#       1138002,
#       1338798,
#       1414969,
#       1651907,
#       1686733,
#       2046662},
#      'leafs': {}},
#     'Neutron diffraction': {'nodes': {58401}, 'leafs': {}},
#     'Hamiltonian (control theory)': {'nodes': {59784,
#       262920,
#       697014,
#       920746,
#       1122632,
#       1201173,
#       1248058},
#      'leafs': {}},
#     'Density functional theory': {'nodes': {60204}, 'leafs': {}},
#     'Vortex': {'nodes': {63689,
#       181546,
#       218236,
#       509349,
#       535763,
#       617188,
#       893053,
#       1046465,
#       1102242,
#       1182553,
#       1239498,
#       1240129,
#       1404812,
#       2005210},
#      'leafs': {}},
#     'Microscopic theory': {'nodes': {65137}, 'leafs': {}},
#     'Electric field': {'nodes': {65987, 656817, 905368, 1897250}, 'leafs': {}},
#     'Path integral formulation': {'nodes': {69219}, 'leafs': {}},
#     'Muon spin spectroscopy': {'nodes': {70334,
#       517323,
#       839289,
#       997056,
#       1038679,
#       1458513,
#       1639676,
#       1714075,
#       1798918,
#       1825710,
#       1887761},
#      'leafs': {}},
#     'Thermal conductivity': {'nodes': {72591, 368871, 725987, 840472},
#      'leafs': {}},
#     'State (computer science)': {'nodes': {75306, 1182423}, 'leafs': {}},
#     'Ground state': {'nodes': {78129, 837577}, 'leafs': {}},
#     'Vanadium': {'nodes': {81255}, 'leafs': {}},
#     'Muon': {'nodes': {82337}, 'leafs': {}},
#     'Magnetic field': {'nodes': {82773, 112510, 399811, 461906, 1764857},
#      'leafs': {}},
#     'Honeycomb': {'nodes': {105406}, 'leafs': {}},
#     'String (physics)': {'nodes': {106437}, 'leafs': {}},
#     'Optical conductivity': {'nodes': {111709}, 'leafs': {}},
#     'Ohmic contact': {'nodes': {112031}, 'leafs': {}},
#     'Theoretical physics': {'nodes': {115691,
#       737555,
#       766355,
#       1359358,
#       1894355,
#       1995216,
#       2035361},
#      'leafs': {}},
#     'Tin': {'nodes': {119199, 547872, 596918, 1250800}, 'leafs': {}},
#     'Magnetic susceptibility': {'nodes': {125273, 1559716}, 'leafs': {}},
#     'Stoichiometry': {'nodes': {129174, 249786}, 'leafs': {}},
#     'Randomness': {'nodes': {129344}, 'leafs': {}},
#     'Degenerate energy levels': {'nodes': {135515, 494580}, 'leafs': {}},
#     'Quantum oscillations': {'nodes': {139474}, 'leafs': {}},
#     'Spins': {'nodes': {150745}, 'leafs': {}},
#     'Dissipation': {'nodes': {156039}, 'leafs': {}},
#     'Cadmium': {'nodes': {156930}, 'leafs': {}},
#     'Annihilation': {'nodes': {165702, 1166123}, 'leafs': {}},
#     'Statistical physics': {'nodes': {185112, 731299}, 'leafs': {}},
#     'Annealing (glass)': {'nodes': {193184, 1064465}, 'leafs': {}},
#     'Mean free path': {'nodes': {193507}, 'leafs': {}},
#     'CHAOS (operating system)': {'nodes': {196358}, 'leafs': {}},
#     'Knight shift': {'nodes': {197298}, 'leafs': {}},
#     'Anyon': {'nodes': {209328}, 'leafs': {}},
#     'Penetration depth': {'nodes': {228369, 641552, 1939749}, 'leafs': {}},
#     'Ginzburg–Landau theory': {'nodes': {252870,
#       376799,
#       854606,
#       1225515,
#       1230649,
#       1587753},
#      'leafs': {}},
#     'Photoemission spectroscopy': {'nodes': {254257, 1837722}, 'leafs': {}},
#     'Crossover': {'nodes': {267315}, 'leafs': {}},
#     'Renormalization group': {'nodes': {270740, 630286}, 'leafs': {}},
#     'Type (biology)': {'nodes': {279592, 1923048}, 'leafs': {}},
#     'Magnetic relaxation': {'nodes': {296545}, 'leafs': {}},
#     'Angular momentum': {'nodes': {304039}, 'leafs': {}},
#     'Nuclear engineering': {'nodes': {307258}, 'leafs': {}},
#     'Phase diagram': {'nodes': {314991,
#       544039,
#       718568,
#       888143,
#       1019050,
#       1139040,
#       1213544,
#       1396208,
#       1588914,
#       1704583,
#       1833297,
#       1908445},
#      'leafs': {}},
#     'Discontinuity (linguistics)': {'nodes': {329236}, 'leafs': {}},
#     'Cyclotron': {'nodes': {330345}, 'leafs': {}},
#     'Boron': {'nodes': {339112}, 'leafs': {}},
#     'Josephson effect': {'nodes': {341206, 1155319, 1721562}, 'leafs': {}},
#     'Oxygen': {'nodes': {352013, 1183003}, 'leafs': {}},
#     'Ab initio': {'nodes': {356290, 1881842}, 'leafs': {}},
#     'Renormalization': {'nodes': {359263}, 'leafs': {}},
#     'Nonlinear system': {'nodes': {368503}, 'leafs': {}},
#     'Raman spectroscopy': {'nodes': {375450, 853861, 924078, 2024633},
#      'leafs': {}},
#     'Magnetization': {'nodes': {375472, 633650, 938431}, 'leafs': {}},
#     'Coulomb blockade': {'nodes': {398084}, 'leafs': {}},
#     'Inversion (geology)': {'nodes': {413632}, 'leafs': {}},
#     'Interpretation (philosophy)': {'nodes': {420191}, 'leafs': {}},
#     'Extrapolation': {'nodes': {428346}, 'leafs': {}},
#     'Correlation function (quantum field theory)': {'nodes': {435612},
#      'leafs': {}},
#     'Electronic structure': {'nodes': {438986,
#       456958,
#       658016,
#       1281430,
#       1639635,
#       1666583},
#      'leafs': {}},
#     'Monotonic function': {'nodes': {448552, 1942907}, 'leafs': {}},
#     'Realization (probability)': {'nodes': {452110}, 'leafs': {}},
#     'Magnetic flux': {'nodes': {455176, 967870}, 'leafs': {}},
#     'Curvature': {'nodes': {464609, 1666414}, 'leafs': {}},
#     'Sigma': {'nodes': {465185}, 'leafs': {}},
#     'Bloch wave': {'nodes': {474038}, 'leafs': {}},
#     'Backflow': {'nodes': {479104}, 'leafs': {}},
#     'Nucleation': {'nodes': {485857, 927059}, 'leafs': {}},
#     'Instanton': {'nodes': {494002}, 'leafs': {}},
#     'BCS theory': {'nodes': {500706, 710919, 1366595}, 'leafs': {}},
#     'Angle-resolved photoemission spectroscopy': {'nodes': {503766, 868318},
#      'leafs': {}},
#     'Aspect ratio (aeronautics)': {'nodes': {514474}, 'leafs': {}},
#     'Boundary value problem': {'nodes': {515658, 600346, 628209}, 'leafs': {}},
#     'Heavy fermion': {'nodes': {517883}, 'leafs': {}},
#     'Ionic radius': {'nodes': {529184}, 'leafs': {}},
#     'Pauli exclusion principle': {'nodes': {529226, 2034295}, 'leafs': {}},
#     'Phase boundary': {'nodes': {529419, 994327}, 'leafs': {}},
#     'Mesoscopic physics': {'nodes': {550520}, 'leafs': {}},
#     'String theory': {'nodes': {550530}, 'leafs': {}},
#     'Quantum': {'nodes': {562999}, 'leafs': {}},
#     'Non-equilibrium thermodynamics': {'nodes': {565571}, 'leafs': {}},
#     'Topology (electrical circuits)': {'nodes': {576375,
#       1046486,
#       1069179,
#       1112210,
#       1176612,
#       1254514,
#       1649345,
#       1722341,
#       1745615,
#       1747192,
#       1806054,
#       1812812,
#       1863458,
#       1902467,
#       1980097},
#      'leafs': {}},
#     'Dual (grammatical number)': {'nodes': {582082}, 'leafs': {}},
#     'Symmetry (geometry)': {'nodes': {583914,
#       1649398,
#       1704290,
#       1763998,
#       1851192,
#       1954477},
#      'leafs': {}},
#     'Limit (mathematics)': {'nodes': {596758, 1614567, 1838410}, 'leafs': {}},
#     'Faraday cage': {'nodes': {600044}, 'leafs': {}},
#     'Current (fluid)': {'nodes': {604989, 803560, 1038251, 1321053},
#      'leafs': {}},
#     'Duality (order theory)': {'nodes': {609170}, 'leafs': {}},
#     'Relaxation (psychology)': {'nodes': {619954}, 'leafs': {}},
#     'Percolation (cognitive psychology)': {'nodes': {629891}, 'leafs': {}},
#     'Chemistry': {'nodes': {642205}, 'leafs': {}},
#     'Computer science': {'nodes': {670176, 1614920}, 'leafs': {}},
#     'Superconducting coherence length': {'nodes': {672865, 1371467},
#      'leafs': {}},
#     'Holography': {'nodes': {674321}, 'leafs': {}},
#     'Anharmonicity': {'nodes': {678697, 1665961}, 'leafs': {}},
#     'Attenuation': {'nodes': {692172, 1125588, 1208302}, 'leafs': {}},
#     'Anomaly (physics)': {'nodes': {697777}, 'leafs': {}},
#     'Phase transition': {'nodes': {703514, 1923035}, 'leafs': {}},
#     'Massless particle': {'nodes': {712935, 2021612}, 'leafs': {}},
#     'Sigma model': {'nodes': {718304}, 'leafs': {}},
#     'Coherence (philosophical gambling strategy)': {'nodes': {724866},
#      'leafs': {}},
#     'Diamond': {'nodes': {726838}, 'leafs': {}},
#     'Frame (networking)': {'nodes': {727602}, 'leafs': {}},
#     'Pseudogap': {'nodes': {727975, 875986, 1657759, 1669314, 1843654},
#      'leafs': {}},
#     'Valence (chemistry)': {'nodes': {728668,
#       830968,
#       837792,
#       1238474,
#       1282930,
#       1319237},
#      'leafs': {}},
#     'Charge density wave': {'nodes': {731763, 1373741}, 'leafs': {}},
#     'Formalism (music)': {'nodes': {752773, 1121675, 1795794}, 'leafs': {}},
#     'Knot (papermaking)': {'nodes': {753015}, 'leafs': {}},
#     'Amplitude': {'nodes': {789600, 799415, 1261758, 1340284, 1765731},
#      'leafs': {}},
#     'Saddle': {'nodes': {790216}, 'leafs': {}},
#     'Coupling constant': {'nodes': {812178}, 'leafs': {}},
#     'Andreev reflection': {'nodes': {812245,
#       1161046,
#       1244185,
#       1458205,
#       1538258,
#       1733264,
#       1972014},
#      'leafs': {}},
#     'Parity (physics)': {'nodes': {815751, 1447674}, 'leafs': {}},
#     'Persistent current': {'nodes': {827338}, 'leafs': {}},
#     'Limiting': {'nodes': {837537}, 'leafs': {}},
#     'Center (category theory)': {'nodes': {847887}, 'leafs': {}},
#     'Supergravity': {'nodes': {856356}, 'leafs': {}},
#     'Quantum decoherence': {'nodes': {868807}, 'leafs': {}},
#     'Quantum nonlocality': {'nodes': {876558}, 'leafs': {}},
#     'Gauge theory': {'nodes': {878435}, 'leafs': {}},
#     'Raman scattering': {'nodes': {879410, 1728675}, 'leafs': {}},
#     'Grüneisen parameter': {'nodes': {895438}, 'leafs': {}},
#     'Ion': {'nodes': {907106}, 'leafs': {}},
#     'Semiclassical physics': {'nodes': {910470}, 'leafs': {}},
#     'Lanczos resampling': {'nodes': {913642}, 'leafs': {}},
#     'Infrared': {'nodes': {917492}, 'leafs': {}},
#     'Intermetallic': {'nodes': {917902}, 'leafs': {}},
#     'Observable': {'nodes': {921169, 1867019, 2028607}, 'leafs': {}},
#     'Homogeneous': {'nodes': {930560}, 'leafs': {}},
#     'Isostructural': {'nodes': {969169}, 'leafs': {}},
#     'Resistive touchscreen': {'nodes': {971653, 1400137}, 'leafs': {}},
#     'Point reflection': {'nodes': {983838, 1871033}, 'leafs': {}},
#     'Squid': {'nodes': {995753, 1354158, 1874891}, 'leafs': {}},
#     'Gauge (firearms)': {'nodes': {1000114}, 'leafs': {}},
#     'Superconducting transition temperature': {'nodes': {1003075},
#      'leafs': {}},
#     'Instability': {'nodes': {1015586}, 'leafs': {}},
#     'Fermi energy': {'nodes': {1018302}, 'leafs': {}},
#     'Dissipative system': {'nodes': {1041568}, 'leafs': {}},
#     'Inverse': {'nodes': {1042250}, 'leafs': {}},
#     'Integral equation': {'nodes': {1058111}, 'leafs': {}},
#     'Random phase approximation': {'nodes': {1069355}, 'leafs': {}},
#     'Boundary (topology)': {'nodes': {1077113}, 'leafs': {}},
#     'Supercurrent': {'nodes': {1078920, 1804830, 1970684}, 'leafs': {}},
#     'Perturbation theory (quantum mechanics)': {'nodes': {1080804},
#      'leafs': {}},
#     'Particle (ecology)': {'nodes': {1096590}, 'leafs': {}},
#     'Euclidean geometry': {'nodes': {1100916}, 'leafs': {}},
#     'Quantum dot': {'nodes': {1116013}, 'leafs': {}},
#     'Fermi surface': {'nodes': {1116638, 1714652}, 'leafs': {}},
#     'Thermodynamics': {'nodes': {1116746}, 'leafs': {}},
#     'Rydberg formula': {'nodes': {1117078}, 'leafs': {}},
#     'Nonmetal': {'nodes': {1148113}, 'leafs': {}},
#     'Transition temperature': {'nodes': {1152105, 1734548}, 'leafs': {}},
#     'Type-II superconductor': {'nodes': {1154541, 1598579}, 'leafs': {}},
#     'Crystallite': {'nodes': {1155420}, 'leafs': {}},
#     'Composite number': {'nodes': {1160605}, 'leafs': {}},
#     'Osmium': {'nodes': {1165500}, 'leafs': {}},
#     'Cubic crystal system': {'nodes': {1169766}, 'leafs': {}},
#     'Fermi liquid theory': {'nodes': {1178704}, 'leafs': {}},
#     'Saddle point': {'nodes': {1192000}, 'leafs': {}},
#     'Kinetic isotope effect': {'nodes': {1204562}, 'leafs': {}},
#     'Cooper pair': {'nodes': {1212683, 1922313, 1938202}, 'leafs': {}},
#     'Charge (physics)': {'nodes': {1247967,
#       1482373,
#       1495052,
#       1791550,
#       1823457,
#       1857542},
#      'leafs': {}},
#     'Basal plane': {'nodes': {1256286}, 'leafs': {}},
#     'Reflectivity': {'nodes': {1259537}, 'leafs': {}},
#     'Graphene': {'nodes': {1294404, 1661311}, 'leafs': {}},
#     'Microwave': {'nodes': {1337315, 1414084}, 'leafs': {}},
#     'Invariant (physics)': {'nodes': {1376762}, 'leafs': {}},
#     'High-temperature superconductivity': {'nodes': {1384111}, 'leafs': {}},
#     'Quenching (fluorescence)': {'nodes': {1388631}, 'leafs': {}},
#     'Supersymmetry': {'nodes': {1397971}, 'leafs': {}},
#     'Critical current': {'nodes': {1412999, 1547808}, 'leafs': {}},
#     'Mössbauer spectroscopy': {'nodes': {1457823}, 'leafs': {}},
#     'Wave function': {'nodes': {1461001}, 'leafs': {}},
#     'Momentum (technical analysis)': {'nodes': {1467555}, 'leafs': {}},
#     'Octahedron': {'nodes': {1480447, 1891533}, 'leafs': {}},
#     'Symmetry breaking': {'nodes': {1528234}, 'leafs': {}},
#     'MAJORANA': {'nodes': {1534417, 1864145, 1895574}, 'leafs': {}},
#     'Mott insulator': {'nodes': {1571567}, 'leafs': {}},
#     'Plane (geometry)': {'nodes': {1597626}, 'leafs': {}},
#     'Praseodymium': {'nodes': {1642993}, 'leafs': {}},
#     'Sound (geography)': {'nodes': {1650861}, 'leafs': {}},
#     'T-symmetry': {'nodes': {1651565}, 'leafs': {}},
#     'Slave boson': {'nodes': {1653660}, 'leafs': {}},
#     'Quantum Monte Carlo': {'nodes': {1658474, 2005361}, 'leafs': {}},
#     'Seebeck coefficient': {'nodes': {1658559, 1801167}, 'leafs': {}},
#     'Exponent': {'nodes': {1661358}, 'leafs': {}},
#     'Particle physics': {'nodes': {1684068}, 'leafs': {}},
#     'Wannier function': {'nodes': {1694877}, 'leafs': {}},
#     'Basis (linear algebra)': {'nodes': {1707052}, 'leafs': {}},
#     'Magnetism': {'nodes': {1710707, 1835320}, 'leafs': {}},
#     'Density of states': {'nodes': {1712377}, 'leafs': {}},
#     'Spin (aerodynamics)': {'nodes': {1712588, 1915888}, 'leafs': {}},
#     'Approx': {'nodes': {1714892}, 'leafs': {}},
#     'Kerr effect': {'nodes': {1734082}, 'leafs': {}},
#     'Phenanthrene': {'nodes': {1750017}, 'leafs': {}},
#     'Imaging phantom': {'nodes': {1752937}, 'leafs': {}},
#     'Nuclear physics': {'nodes': {1760592}, 'leafs': {}},
#     'London penetration depth': {'nodes': {1766915, 1822538}, 'leafs': {}},
#     'Ternary operation': {'nodes': {1778106}, 'leafs': {}},
#     'Magnetometer': {'nodes': {1787681}, 'leafs': {}},
#     'Mirror symmetry': {'nodes': {1788071}, 'leafs': {}},
#     'Superlattice': {'nodes': {1789336, 2013469}, 'leafs': {}},
#     'Scandium': {'nodes': {1790593}, 'leafs': {}},
#     'Homogeneous space': {'nodes': {1793236, 1807546}, 'leafs': {}},
#     'Zero-point energy': {'nodes': {1806215}, 'leafs': {}},
#     'Similarity (geometry)': {'nodes': {1822044}, 'leafs': {}},
#     'Topological insulator': {'nodes': {1827650, 1998565, 2046654},
#      'leafs': {}},
#     'Substrate (aquarium)': {'nodes': {1836071}, 'leafs': {}},
#     'Quantum critical point': {'nodes': {1837319}, 'leafs': {}},
#     'Higgs boson': {'nodes': {1861246}, 'leafs': {}},
#     'Jahn–Teller effect': {'nodes': {1867260}, 'leafs': {}},
#     'Heavy fermion superconductor': {'nodes': {1875310}, 'leafs': {}},
#     'Atomic orbital': {'nodes': {1887098}, 'leafs': {}},
#     'Polyhedron': {'nodes': {1892248}, 'leafs': {}},
#     'Chaotic': {'nodes': {1893378}, 'leafs': {}},
#     'Semimetal': {'nodes': {1894854, 1965425}, 'leafs': {}},
#     'Quadrupole': {'nodes': {1900236}, 'leafs': {}},
#     'Skutterudite': {'nodes': {1911629}, 'leafs': {}},
#     'Quasiperiodic function': {'nodes': {1915301}, 'leafs': {}},
#     'Algorithm': {'nodes': {1915762}, 'leafs': {}},
#     'Harmonic': {'nodes': {1922857}, 'leafs': {}},
#     'Wigner distribution function': {'nodes': {1970193}, 'leafs': {}},
#     'Thermalisation': {'nodes': {1970685}, 'leafs': {}},
#     'Femtosecond': {'nodes': {1978460}, 'leafs': {}},
#     'Periodic table': {'nodes': {1983167}, 'leafs': {}},
#     'Nabla symbol': {'nodes': {1985156}, 'leafs': {}},
#     'Bismuth': {'nodes': {2025240}, 'leafs': {}},
#     'Gapless playback': {'nodes': {2034112}, 'leafs': {}}}},
#   'Condensed matter physics': {'nodes': set(),
#    'leafs': {'Work function': {'nodes': {332}, 'leafs': {}},
#     'Superheating': {'nodes': {1423, 460377}, 'leafs': {}},
#     'Kinetic isotope effect': {'nodes': {1753}, 'leafs': {}},
#     'Josephson effect': {'nodes': {2021,
#       146944,
#       148555,
#       209362,
#       222008,
#       225652,
#       276546,
#       337579,
#       375331,
#       385420,
#       392143,
#       432470,
#       624869,
#       671584,
#       678454,
#       690494,
#       691957,
#       755939,
#       904066,
#       964298,
#       1144394,
#       1148625,
#       1156861,
#       1167635,
#       1179188,
#       1191717,
#       1405477,
#       1493347,
#       1645150,
#       1903168,
#       1937604},
#      'leafs': {}},
#     'Quasiparticle': {'nodes': {2914,
#       13193,
#       22136,
#       38895,
#       72885,
#       79353,
#       135738,
#       244970,
#       319503,
#       351397,
#       357332,
#       373420,
#       392236,
#       552168,
#       568005,
#       629157,
#       642471,
#       695979,
#       705888,
#       786490,
#       808705,
#       885362,
#       892360,
#       900248,
#       909863,
#       938414,
#       993451,
#       995815,
#       1028821,
#       1031683,
#       1168429,
#       1177697,
#       1188024,
#       1270701,
#       1349701,
#       1355305,
#       1388347,
#       1395487,
#       1463257,
#       1516680,
#       1582125,
#       1622109,
#       1668130,
#       1687250,
#       1797761,
#       1829267,
#       1922048,
#       1926452,
#       1939485,
#       1956080,
#       1966449},
#      'leafs': {}},
#     'Saturation (graph theory)': {'nodes': {3253}, 'leafs': {}},
#     'Valence band': {'nodes': {3546}, 'leafs': {}},
#     'Physics': {'nodes': {4045,
#       7085,
#       7816,
#       9365,
#       9747,
#       10334,
#       12000,
#       15107,
#       18032,
#       18115,
#       18593,
#       19346,
#       21926,
#       23106,
#       23516,
#       24177,
#       24328,
#       28649,
#       29767,
#       29804,
#       31284,
#       34151,
#       36168,
#       38250,
#       39956,
#       42662,
#       43438,
#       44885,
#       45113,
#       45381,
#       45831,
#       46381,
#       49085,
#       49325,
#       49890,
#       53566,
#       53672,
#       53905,
#       54845,
#       55617,
#       56182,
#       59809,
#       66206,
#       67668,
#       69703,
#       71278,
#       73128,
#       76253,
#       77459,
#       78959,
#       80085,
#       83948,
#       85455,
#       91240,
#       102931,
#       105592,
#       107223,
#       109640,
#       117526,
#       122878,
#       124421,
#       125670,
#       126600,
#       134945,
#       136101,
#       138578,
#       147859,
#       151279,
#       156686,
#       157039,
#       158842,
#       159529,
#       160820,
#       166284,
#       166488,
#       184712,
#       187248,
#       194620,
#       199297,
#       201870,
#       202075,
#       202287,
#       209174,
#       212422,
#       215389,
#       215858,
#       217985,
#       228360,
#       229986,
#       230150,
#       233155,
#       233745,
#       238048,
#       239004,
#       242889,
#       244038,
#       247177,
#       249782,
#       256213,
#       256811,
#       256898,
#       257387,
#       261139,
#       274163,
#       275309,
#       283293,
#       284444,
#       288394,
#       288917,
#       289741,
#       290093,
#       290964,
#       292533,
#       294498,
#       302002,
#       303415,
#       306900,
#       309789,
#       313921,
#       314066,
#       315617,
#       315795,
#       316237,
#       319798,
#       326922,
#       332424,
#       335930,
#       336483,
#       337094,
#       339048,
#       341121,
#       348091,
#       348731,
#       354278,
#       354666,
#       357362,
#       358368,
#       359486,
#       363824,
#       364991,
#       366325,
#       366691,
#       368502,
#       371992,
#       375446,
#       378314,
#       378619,
#       379916,
#       384519,
#       386546,
#       389963,
#       393373,
#       395425,
#       396284,
#       397081,
#       401051,
#       401207,
#       402143,
#       405315,
#       406319,
#       407249,
#       408960,
#       410575,
#       418488,
#       419163,
#       420078,
#       421354,
#       423612,
#       423908,
#       427462,
#       431627,
#       432227,
#       432864,
#       436202,
#       439244,
#       440520,
#       443207,
#       447030,
#       448971,
#       452465,
#       459912,
#       461568,
#       462645,
#       469840,
#       471467,
#       474574,
#       481786,
#       484896,
#       492727,
#       492996,
#       502474,
#       503348,
#       508399,
#       511109,
#       530163,
#       534449,
#       534782,
#       537841,
#       541683,
#       542376,
#       544208,
#       545177,
#       547532,
#       547803,
#       548871,
#       550871,
#       552861,
#       554277,
#       556947,
#       557201,
#       562008,
#       564770,
#       567049,
#       568575,
#       570438,
#       572439,
#       579337,
#       585516,
#       589299,
#       593428,
#       593921,
#       598230,
#       598285,
#       598790,
#       598986,
#       601588,
#       605223,
#       607499,
#       611975,
#       612568,
#       613754,
#       613835,
#       621417,
#       626302,
#       633623,
#       637214,
#       642761,
#       646459,
#       646644,
#       651557,
#       660455,
#       661838,
#       665213,
#       668715,
#       670545,
#       672559,
#       674714,
#       675674,
#       685546,
#       686510,
#       690185,
#       693521,
#       694961,
#       710085,
#       711891,
#       713262,
#       720402,
#       720993,
#       723650,
#       727429,
#       737839,
#       739015,
#       742462,
#       748354,
#       748394,
#       748772,
#       750360,
#       751402,
#       756599,
#       759584,
#       763358,
#       768691,
#       771300,
#       772851,
#       774334,
#       774698,
#       776892,
#       778396,
#       780579,
#       781240,
#       781732,
#       784343,
#       785259,
#       786738,
#       788848,
#       790234,
#       791385,
#       805828,
#       806345,
#       810667,
#       811353,
#       813538,
#       820468,
#       824628,
#       826081,
#       827558,
#       828521,
#       830101,
#       830542,
#       833066,
#       836409,
#       837010,
#       839094,
#       840684,
#       841213,
#       841358,
#       842955,
#       844094,
#       845316,
#       847993,
#       851228,
#       852717,
#       853514,
#       853605,
#       857763,
#       859835,
#       862721,
#       876656,
#       878440,
#       880444,
#       882053,
#       883287,
#       889382,
#       890987,
#       892156,
#       897806,
#       901737,
#       903939,
#       909264,
#       910051,
#       911073,
#       912938,
#       916346,
#       918118,
#       926898,
#       927424,
#       928207,
#       934256,
#       938653,
#       940424,
#       942743,
#       943427,
#       944910,
#       949014,
#       951016,
#       951643,
#       953754,
#       956923,
#       959159,
#       959645,
#       959841,
#       960113,
#       971620,
#       971966,
#       974787,
#       975360,
#       982124,
#       985660,
#       995355,
#       1000092,
#       1002938,
#       1005236,
#       1008428,
#       1008815,
#       1019123,
#       1019494,
#       1022501,
#       1039597,
#       1046681,
#       1050470,
#       1051234,
#       1061791,
#       1066861,
#       1070246,
#       1070851,
#       1071686,
#       1073615,
#       1075908,
#       1076027,
#       1078504,
#       1079293,
#       1079563,
#       1085074,
#       1090700,
#       1091806,
#       1099445,
#       1107920,
#       1108925,
#       1111960,
#       1120585,
#       1121701,
#       1125605,
#       1131267,
#       1140375,
#       1141612,
#       1143104,
#       1143217,
#       1153036,
#       1154085,
#       1155795,
#       1156838,
#       1160087,
#       1163093,
#       1163651,
#       1175870,
#       1181612,
#       1187309,
#       1199273,
#       1201657,
#       1203357,
#       1208463,
#       1210227,
#       1210275,
#       1211730,
#       1211741,
#       1214506,
#       1221938,
#       1223410,
#       1224238,
#       1224517,
#       1231308,
#       1232111,
#       1235773,
#       1238073,
#       1238358,
#       1239954,
#       1241036,
#       1241419,
#       1243097,
#       1249087,
#       1250568,
#       1254230,
#       1260828,
#       1264481,
#       1266599,
#       1268963,
#       1280372,
#       1282788,
#       1284662,
#       1284755,
#       1286828,
#       1287386,
#       1303847,
#       1306261,
#       1306682,
#       1307707,
#       1315389,
#       1315408,
#       1317518,
#       1327952,
#       1330153,
#       1330898,
#       1337998,
#       1341963,
#       1343791,
#       1346625,
#       1348761,
#       1354806,
#       1356661,
#       1358850,
#       1359484,
#       1363503,
#       1363880,
#       1365380,
#       1366691,
#       1379452,
#       1388975,
#       1389884,
#       1390716,
#       1391521,
#       1392779,
#       1403483,
#       1408336,
#       1418830,
#       1421167,
#       1424583,
#       1425118,
#       1428308,
#       1435704,
#       1437506,
#       1439791,
#       1464350,
#       1470833,
#       1472153,
#       1485766,
#       1494930,
#       1498294,
#       1511216,
#       1518506,
#       1524622,
#       1525770,
#       1532521,
#       1533362,
#       1540599,
#       1550032,
#       1556763,
#       1559532,
#       1568770,
#       1600462,
#       1609269,
#       1622302,
#       1629677,
#       1631709,
#       1633359,
#       1634908,
#       1636771,
#       1637041,
#       1639047,
#       1641503,
#       1641648,
#       1643790,
#       1647668,
#       1647810,
#       1648684,
#       1651539,
#       1652056,
#       1654833,
#       1656552,
#       1660014,
#       1661215,
#       1670951,
#       1671952,
#       1676136,
#       1680505,
#       1684571,
#       1689393,
#       1694179,
#       1696047,
#       1698444,
#       1700166,
#       1701410,
#       1702302,
#       1703584,
#       1703598,
#       1705355,
#       1707446,
#       1716401,
#       1719965,
#       1721126,
#       1727507,
#       1738343,
#       1745858,
#       1745921,
#       1747209,
#       1752183,
#       1757663,
#       1764408,
#       1766834,
#       1768396,
#       1768758,
#       1774948,
#       1775524,
#       1776034,
#       1780566,
#       1784541,
#       1784595,
#       1787766,
#       1788138,
#       1789769,
#       1791597,
#       1792457,
#       1792506,
#       1792927,
#       1792955,
#       1793481,
#       1793947,
#       1795477,
#       1796902,
#       1797762,
#       1801111,
#       1802203,
#       1808758,
#       1809172,
#       1811400,
#       1813213,
#       1816761,
#       1817593,
#       1817922,
#       1818816,
#       1823112,
#       1823245,
#       1824932,
#       1827906,
#       1832592,
#       1835605,
#       1838262,
#       1840505,
#       1845624,
#       1846341,
#       1849148,
#       1851706,
#       1852224,
#       1856794,
#       1861405,
#       1865546,
#       1869220,
#       1870243,
#       1876827,
#       1879384,
#       1880051,
#       1881725,
#       1882093,
#       1883911,
#       1884609,
#       1889010,
#       1890987,
#       1891017,
#       1892782,
# ...
#   'Ion milling machine': {'nodes': set(),
#    'leafs': {'Materials science': {'nodes': {1258372}, 'leafs': {}}}},
#   'Finite element method': {'nodes': set(),
#    'leafs': {'Finite volume method': {'nodes': {1260046}, 'leafs': {}},
#     'Representation (politics)': {'nodes': {1570521}, 'leafs': {}}}},
#   'Enhanced Data Rates for GSM Evolution': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': {1286615}, 'leafs': {}},
#     'Spectrometer': {'nodes': {1661751}, 'leafs': {}}}},
#   'Sodium': {'nodes': set(),
#    'leafs': {'Potassium': {'nodes': {1289804}, 'leafs': {}}}},
#   'Microscope': {'nodes': set(),
#    'leafs': {'Quantum tunnelling': {'nodes': {1294965}, 'leafs': {}}}},
#   'Anderson impurity model': {'nodes': set(),
#    'leafs': {'Impurity': {'nodes': {1295455}, 'leafs': {}}}},
#   'Mixed phase': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1313311}, 'leafs': {}}}},
#   'Stars': {'nodes': set(),
#    'leafs': {'Paramagnetism': {'nodes': {1319055}, 'leafs': {}}}},
#   'Gradiometer': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1322245}, 'leafs': {}}}},
#   'Calorimetry': {'nodes': set(),
#    'leafs': {'Materials science': {'nodes': {1324035}, 'leafs': {}}}},
#   'Sigma': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1328205}, 'leafs': {}}}},
#   'Reactivity (psychology)': {'nodes': set(),
#    'leafs': {'Cuprate': {'nodes': {1336870}, 'leafs': {}}}},
#   'Domain wall (magnetism)': {'nodes': set(),
#    'leafs': {'Topology (electrical circuits)': {'nodes': {1340954},
#      'leafs': {}}}},
#   'Strontium titanate': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1355162}, 'leafs': {}}}},
#   'Polyhedron': {'nodes': set(),
#    'leafs': {'Bismuth': {'nodes': {1355181}, 'leafs': {}}}},
#   'Platinum': {'nodes': set(),
#    'leafs': {'Anisotropy': {'nodes': {1361495}, 'leafs': {}}}},
#   'Lanthanide': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1361919}, 'leafs': {}}}},
#   'Salt (chemistry)': {'nodes': set(),
#    'leafs': {'Crystallography': {'nodes': {1365017}, 'leafs': {}}}},
#   'Full width at half maximum': {'nodes': set(),
#    'leafs': {'Materials science': {'nodes': {1367612}, 'leafs': {}},
#     'Condensed matter physics': {'nodes': {2004955}, 'leafs': {}}}},
#   'Magnetite': {'nodes': set(),
#    'leafs': {'Phase (matter)': {'nodes': {1370255}, 'leafs': {}}}},
#   'Font': {'nodes': set(),
#    'leafs': {'Doping': {'nodes': {1370441}, 'leafs': {}},
#     'Physics': {'nodes': {1846162}, 'leafs': {}}}},
#   'Perchlorate': {'nodes': set(),
#    'leafs': {'Organic superconductor': {'nodes': {1373368}, 'leafs': {}}}},
#   'Spectrum (functional analysis)': {'nodes': set(),
#    'leafs': {'Vortex': {'nodes': {1374245}, 'leafs': {}}}},
#   'Lamellar structure': {'nodes': set(),
#    'leafs': {'Graphite': {'nodes': {1374849}, 'leafs': {}}}},
#   'Thermal decomposition': {'nodes': set(),
#    'leafs': {'Thermal stability': {'nodes': {1383893}, 'leafs': {}}}},
#   'Positron annihilation': {'nodes': set(),
#    'leafs': {'Hydrogen': {'nodes': {1384314}, 'leafs': {}}}},
#   'Lattice vibration': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': {1388510}, 'leafs': {}}}},
#   'Microscopic theory': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1392767, 1636665},
#      'leafs': {}},
#     'Physics': {'nodes': {2036340}, 'leafs': {}}}},
#   'Wave function': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1394866}, 'leafs': {}},
#     'Physics': {'nodes': {1624861, 1725330}, 'leafs': {}}}},
#   'Buffer (optical fiber)': {'nodes': set(),
#    'leafs': {'Epitaxy': {'nodes': {1398817}, 'leafs': {}}}},
#   'Wannier function': {'nodes': set(),
#    'leafs': {'Pairing': {'nodes': {1402850}, 'leafs': {}}}},
#   'Magneto optical': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1407356}, 'leafs': {}}}},
#   'Current crowding': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1408132}, 'leafs': {}}}},
#   'Wave equation': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': {1409721}, 'leafs': {}}}},
#   'Dislocation': {'nodes': set(),
#    'leafs': {'Plasticity': {'nodes': {1411685}, 'leafs': {}}}},
#   'Black-body radiation': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1427676}, 'leafs': {}}}},
#   'Isothermal process': {'nodes': set(),
#    'leafs': {'Adiabatic process': {'nodes': {1427997}, 'leafs': {}}}},
#   'Group (periodic table)': {'nodes': set(),
#    'leafs': {'Crystal structure': {'nodes': {1434661}, 'leafs': {}},
#     'Doping': {'nodes': {1756506}, 'leafs': {}}}},
#   'Powder diffraction': {'nodes': set(),
#    'leafs': {'X-ray crystallography': {'nodes': {1441056}, 'leafs': {}}}},
#   'Matrix (chemical analysis)': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': {1441900}, 'leafs': {}}}},
#   'Arrhenius equation': {'nodes': set(),
#    'leafs': {'Tetragonal crystal system': {'nodes': {1447877}, 'leafs': {}}}},
#   'Metamaterial': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1454135}, 'leafs': {}}}},
#   'Superexchange': {'nodes': set(),
#    'leafs': {'Antiferromagnetism': {'nodes': {1456319, 1658958},
#      'leafs': {}}}},
#   'Casimir effect': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': {1466715, 1613488}, 'leafs': {}}}},
#   'Range (aeronautics)': {'nodes': set(),
#    'leafs': {'Theoretical physics': {'nodes': {1467336}, 'leafs': {}}}},
#   'Scalar (mathematics)': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': {1467402}, 'leafs': {}}}},
#   'Tetramer': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1476343}, 'leafs': {}}}},
#   'Injector': {'nodes': set(),
#    'leafs': {'Brightness': {'nodes': {1484894}, 'leafs': {}}}},
#   'Closing (real estate)': {'nodes': set(),
#    'leafs': {'Resistance (ecology)': {'nodes': {1500116}, 'leafs': {}}}},
#   'Specular reflection': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1506275}, 'leafs': {}}}},
#   'Bulk modulus': {'nodes': set(),
#    'leafs': {'Lattice constant': {'nodes': {1519889}, 'leafs': {}}}},
#   'Winding number': {'nodes': set(),
#    'leafs': {'Josephson effect': {'nodes': {1525861}, 'leafs': {}}}},
#   'Loop (graph theory)': {'nodes': set(),
#    'leafs': {'Phase locking': {'nodes': {1531058}, 'leafs': {}},
#     'Physics': {'nodes': {1678393}, 'leafs': {}}}},
#   'Metrology': {'nodes': set(),
#    'leafs': {'Penetration depth': {'nodes': {1541845}, 'leafs': {}}}},
#   'Solvent': {'nodes': set(),
#    'leafs': {'Materials science': {'nodes': {1545593}, 'leafs': {}}}},
#   'Quantum oscillations': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1556865}, 'leafs': {}}}},
#   'Interphase': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1563597}, 'leafs': {}}}},
#   'Scanning transmission electron microscopy': {'nodes': set(),
#    'leafs': {'Materials science': {'nodes': {1567241}, 'leafs': {}}}},
#   'NODAL': {'nodes': set(),
#    'leafs': {'Cuprate': {'nodes': {1569832}, 'leafs': {}}}},
#   'High resolution': {'nodes': set(),
#    'leafs': {'High-temperature superconductivity': {'nodes': {1587265},
#      'leafs': {}}}},
#   'Computation': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': {1592185}, 'leafs': {}}}},
#   'Microwave cavity': {'nodes': set(),
#    'leafs': {'Dielectric': {'nodes': {1614426}, 'leafs': {}}}},
#   'Carbide': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1616916}, 'leafs': {}}}},
#   'Modulation (music)': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1617140}, 'leafs': {}}}},
#   'Fermi gas': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1617143}, 'leafs': {}}}},
#   'Phenomenology (philosophy)': {'nodes': set(),
#    'leafs': {'Specific heat': {'nodes': {1617753}, 'leafs': {}}}},
#   'Isotopes of carbon': {'nodes': set(),
#    'leafs': {'Carbon fibers': {'nodes': {1618634}, 'leafs': {}}}},
#   'Plutonium': {'nodes': set(),
#    'leafs': {'Isostructural': {'nodes': {1624789}, 'leafs': {}}}},
#   'van der Waals force': {'nodes': set(),
#    'leafs': {'Monolayer': {'nodes': {1628056}, 'leafs': {}},
#     'Condensed matter physics': {'nodes': {1808793, 1822770, 1893776},
#      'leafs': {}},
#     'Doping': {'nodes': {1883003, 1884767}, 'leafs': {}},
#     'Superspace': {'nodes': {1892537}, 'leafs': {}},
#     'Heterojunction': {'nodes': {2024627}, 'leafs': {}}}},
#   'Basis (linear algebra)': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1629330}, 'leafs': {}}}},
#   'Oxygen deficiency': {'nodes': set(),
#    'leafs': {'Oxygen': {'nodes': {1629970}, 'leafs': {}}}},
#   'Embedding': {'nodes': set(),
#    'leafs': {'Heterojunction': {'nodes': {1639116}, 'leafs': {}}}},
#   'Commensurability (mathematics)': {'nodes': set(),
#    'leafs': {'Vortex': {'nodes': {1639121}, 'leafs': {}}}},
#   'Similarity (geometry)': {'nodes': set(),
#    'leafs': {'Phonon': {'nodes': {1640458}, 'leafs': {}}}},
#   'Semimetal': {'nodes': set(),
#    'leafs': {'Anisotropy': {'nodes': {1640466}, 'leafs': {}},
#     'Paramagnetism': {'nodes': {1793525}, 'leafs': {}},
#     'Condensed matter physics': {'nodes': {1843336, 1881259}, 'leafs': {}},
#     'Weyl semimetal': {'nodes': {1904955}, 'leafs': {}}}},
#   'Spintronics': {'nodes': set(),
#    'leafs': {'Quasiparticle': {'nodes': {1662061}, 'leafs': {}},
#     'Electronic band': {'nodes': {1852005}, 'leafs': {}},
#     'Spin (aerodynamics)': {'nodes': {1939600}, 'leafs': {}}}},
#   'X-ray crystallography': {'nodes': set(),
#    'leafs': {'Analytical Chemistry (journal)': {'nodes': {1662930},
#      'leafs': {}}}},
#   'Hyperfine structure': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': {1676540}, 'leafs': {}}}},
#   'Dimer': {'nodes': set(),
#    'leafs': {'Crystallography': {'nodes': {1683872}, 'leafs': {}}}},
#   'Argon': {'nodes': set(),
#    'leafs': {'Materials science': {'nodes': {1690377}, 'leafs': {}}}},
#   'Node (physics)': {'nodes': set(),
#    'leafs': {'Quantum tunnelling': {'nodes': {1691077}, 'leafs': {}}}},
#   'Proton': {'nodes': set(),
#    'leafs': {'Electrical resistivity and conductivity': {'nodes': {1696239},
#      'leafs': {}}}},
#   'Honeycomb': {'nodes': set(),
#    'leafs': {'Charge (physics)': {'nodes': {1708146}, 'leafs': {}},
#     'Point reflection': {'nodes': {1967720}, 'leafs': {}}}},
#   'Coplanar waveguide': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1724399}, 'leafs': {}}}},
#   'Monatomic ion': {'nodes': set(),
#    'leafs': {'Cuprate': {'nodes': {1729706}, 'leafs': {}}}},
#   'Cobalt': {'nodes': set(),
#    'leafs': {'Materials science': {'nodes': {1729757}, 'leafs': {}}}},
#   'Technetium': {'nodes': set(),
#    'leafs': {'Crystal structure': {'nodes': {1734058}, 'leafs': {}}}},
#   'Coupling constant': {'nodes': set(),
#    'leafs': {'Phonon': {'nodes': {1739814}, 'leafs': {}}}},
#   'Floquet theory': {'nodes': set(),
#    'leafs': {'Cuprate': {'nodes': {1748328}, 'leafs': {}}}},
#   'Thermal diffusivity': {'nodes': set(),
#    'leafs': {'Materials science': {'nodes': {1752117}, 'leafs': {}}}},
#   'Chirality (physics)': {'nodes': set(),
#    'leafs': {'Supercurrent': {'nodes': {1755276}, 'leafs': {}}}},
#   'Phosphorene': {'nodes': set(),
#    'leafs': {'Intercalation (chemistry)': {'nodes': {1756224}, 'leafs': {}}}},
#   'Cathode ray': {'nodes': set(),
#    'leafs': {'Instability': {'nodes': {1759344}, 'leafs': {}}}},
#   'Surface roughness': {'nodes': set(),
#    'leafs': {'Surface finish': {'nodes': {1764931}, 'leafs': {}}}},
#   'Duality (order theory)': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1775872}, 'leafs': {}}}},
#   'Kinetic inductance': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1776234}, 'leafs': {}}}},
#   'Bromine': {'nodes': set(),
#    'leafs': {'Halogen': {'nodes': {1786585}, 'leafs': {}}}},
#   'Pyrite': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1788018}, 'leafs': {}}}},
#   'Electronics': {'nodes': set(),
#    'leafs': {'Charge (physics)': {'nodes': {1792521}, 'leafs': {}}}},
#   'Polarization (electrochemistry)': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': {1801046}, 'leafs': {}}}},
#   'Milestone': {'nodes': set(),
#    'leafs': {'Hydrogen sulfide': {'nodes': {1801379}, 'leafs': {}}}},
#   'Renormalization group': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1809003}, 'leafs': {}}}},
#   'Flux method': {'nodes': set(),
#    'leafs': {'Ferromagnetism': {'nodes': {1819769}, 'leafs': {}}}},
#   'Sulfide': {'nodes': set(),
#    'leafs': {'Materials science': {'nodes': {1820439}, 'leafs': {}}}},
#   'Weyl semimetal': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1834247}, 'leafs': {}},
#     'Doping': {'nodes': {1924074}, 'leafs': {}}}},
#   'Electronegativity': {'nodes': set(),
#    'leafs': {'Crystallography': {'nodes': {1840189}, 'leafs': {}}}},
#   'Spin–orbit interaction': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': {1857465}, 'leafs': {}}}},
#   'Periodic table': {'nodes': set(),
#    'leafs': {'Deep learning': {'nodes': {1860670}, 'leafs': {}}}},
#   'Energy landscape': {'nodes': set(),
#    'leafs': {'Energy (signal processing)': {'nodes': {1875319}, 'leafs': {}}}},
#   'Unitary state': {'nodes': set(),
#    'leafs': {'Dirac (video compression format)': {'nodes': {1881298},
#      'leafs': {}}}},
#   'Bearing (navigation)': {'nodes': set(),
#    'leafs': {'Phenomenology (philosophy)': {'nodes': {1902102}, 'leafs': {}}}},
#   'Image warping': {'nodes': set(),
#    'leafs': {'Pairing': {'nodes': {1902472}, 'leafs': {}}}},
#   'Praseodymium': {'nodes': set(),
#    'leafs': {'Non-blocking I/O': {'nodes': {1913137}, 'leafs': {}}}},
#   'Scalar field': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1924228}, 'leafs': {}}}},
#   'Samarium': {'nodes': set(),
#    'leafs': {'Electrical resistivity and conductivity': {'nodes': {1931814},
#      'leafs': {}}}},
#   'Spin valve': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1935338}, 'leafs': {}}}},
#   'Hexamethylenediamine': {'nodes': set(),
#    'leafs': {'Annealing (glass)': {'nodes': {1937578}, 'leafs': {}}}},
#   'Style (visual arts)': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1942608}, 'leafs': {}}}},
#   'Magnetic flux quantum': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1949548}, 'leafs': {}}}},
#   'Optoelectronics': {'nodes': set(),
#    'leafs': {'Antenna (radio)': {'nodes': {1950337}, 'leafs': {}}}},
#   'Refrigeration': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {1951160}, 'leafs': {}}}},
#   'Phenomenon': {'nodes': set(),
#    'leafs': {'Theoretical physics': {'nodes': {1960542}, 'leafs': {}},
#     'Pleasure': {'nodes': {2032469}, 'leafs': {}}}},
#   'Causality (physics)': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': {1966173}, 'leafs': {}}}},
#   'Parameter space': {'nodes': set(),
#    'leafs': {'Bifurcation': {'nodes': {1968608}, 'leafs': {}}}},
#   'Oxidizing agent': {'nodes': set(),
#    'leafs': {'Annealing (glass)': {'nodes': {1978206}, 'leafs': {}}}},
#   'Compendium': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': {1987499}, 'leafs': {}}}},
#   'High entropy alloys': {'nodes': set(),
#    'leafs': {'Materials science': {'nodes': {1993711}, 'leafs': {}}}},
#   'Phosphide': {'nodes': set(),
#    'leafs': {'Lattice constant': {'nodes': {1994659}, 'leafs': {}},
#     'Condensed matter physics': {'nodes': {2010671}, 'leafs': {}}}},
#   'Triclinic crystal system': {'nodes': set(),
#    'leafs': {'Arsenide': {'nodes': {1996700}, 'leafs': {}}}},
#   'Cage': {'nodes': set(),
#    'leafs': {'Materials science': {'nodes': {2009947}, 'leafs': {}}}},
#   'Circulator': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': {2013075}, 'leafs': {}}}},
#   'Muon': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': {2025351}, 'leafs': {}}}},
#   'Library science': {'nodes': set(),
#    'leafs': {'Engineering physics': {'nodes': {2030949}, 'leafs': {}}}},
#   'BETA (programming language)': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': {2036214}, 'leafs': {}}}},
#   'Oxonium ion': {'nodes': set(),
#    'leafs': {'Phase diagram': {'nodes': {2046498}, 'leafs': {}}}}}}

# %%
df.iloc[list(tree["Superconductivity"]["nodes"])]
# Out:
# Empty DataFrame
# Columns: [id, abstract, title, publication_date, keywords, concepts]
# Index: []

# %%
df.iloc[sorted(list(sum_tree_nodes(tree["Physics"]["leafs"], visited=set())))]
# Out:
#                                        id  \
# 2         https://openalex.org/W100006313
# 5         https://openalex.org/W100035585
# 9        https://openalex.org/W1000585164
# 10       https://openalex.org/W1000603767
# 17         https://openalex.org/W10010732
# ...                                   ...
# 2048696    https://openalex.org/W99876827
# 2048700    https://openalex.org/W99919431
# 2048701    https://openalex.org/W99922069
# 2048704    https://openalex.org/W99994197
# 2048705   https://openalex.org/W999961912
#
#                                                   abstract  \
# 2        in a wire spark-chamber experiment the squared...
# 5        motivated by the peculiar features observed th...
# 9        in this work, we study systems composed of a $...
# 10       quantum steering inequalities allow to demonst...
# 17       an estimate of the magnitude of the $\mathrm{s...
# ...                                                    ...
# 2048696  we consider the decay ${b}^{0}(t)\ensuremath{\...
# 2048700  we report a high-statistics experiment measuri...
# 2048701  we have done a new evaluation of the lowest-or...
# 2048704  measurements are reported of the transmission ...
# 2048705  this chapter reviews the computational methods...
#
#                                                      title publication_date  \
# 2        experimental study on the τ± decay matrix element       1972-03-01
# 5                 nonlinearc-axis transport inbi2sr2cacu2o       2009-04-01
# 9        the $$\rho (\omega ) b^* (b)$$ ρ ( ω ) b ∗ ( b...       2016-02-01
# 10       einstein-podolsky-rosen steering: closing the ...       2013-02-13
# 17       the (1, 8)+(8, 1) term insu(3)×su(3)symmetry b...       1971-07-01
# ...                                                    ...              ...
# 2048696  newcpobservables inb0(t)→hyperon+antihyperonfr...       1998-10-29
# 2048700  observation of coherent interference pattern b...       1970-11-09
# 2048701  hadronic part of the muon anomalous magnetic m...       1990-08-01
# 2048704             infrared optical excitations inla2nio4       1995-10-01
# 2048705  energies and asymptotic analysis for helium ry...       1993-01-01
#
#                                                   keywords  \
# 2                                               ['matrix']
# 5          ['transport', 'nonlinearc-axis', 'two-barrier']
# 9                                          ['interaction']
# 10       ['detection loophole', 'einstein-podolsky-rose...
# 17                                   ['insu3×su3symmetry']
# ...                                                    ...
# 2048696                      ['parity violation', 'decay']
# 2048700  ['coherent interference pattern', 'between<mml...
# 2048701  ['anomalous magnetic moment', 'muon', 'hadroni...
# 2048704                   ['infrared optical excitations']
# 2048705                            ['asymptotic analysis']
#
#                                                   concepts
# 2        [('Physics', 0.9268166), ('Matrix element', 0....
# 5        [('Physics', 0.73089707), ('Pseudogap', 0.6889...
# 9        [('Physics', 0.83831257), ('Omega', 0.82759345...
# 10       [('Physics', 0.90650284), ('Quantum key distri...
# 17       [('Physics', 0.590814), ('Symmetry breaking', ...
# ...                                                    ...
# 2048696  [('Physics', 0.8435714), ('Hyperon', 0.5917092...
# 2048700  [('Physics', 0.75475097), ('Omega', 0.7398769)...
# 2048701  [('Physics', 0.8732732), ('Muon', 0.7624949), ...
# 2048704  [('Physics', 0.62062633), ('Absorption (acoust...
# 2048705  [('Physics', 0.88181573), ('Rydberg formula', ...
#
# [441914 rows x 6 columns]

# %%
# Symmetry breaking

# %%
k = "Hyperon"
df.iloc[sorted(list(tree[k]["nodes"] | sum_tree_nodes(tree[k]["leafs"], visited=set())))]
# Out:
#                                        id  \
# 8574     https://openalex.org/W1493763504
# 9577     https://openalex.org/W1497134819
# 10957    https://openalex.org/W1501775630
# 14937    https://openalex.org/W1515654579
# 19113    https://openalex.org/W1531116484
# ...                                   ...
# 2031752  https://openalex.org/W4235095995
# 2031995  https://openalex.org/W4235644188
# 2035163  https://openalex.org/W4242816380
# 2037660  https://openalex.org/W4248651992
# 2043162    https://openalex.org/W52729515
#
#                                                   abstract  \
# 8574     the properties of \ensuremath{\sigma}-hyperons...
# 9577     by using resonance model, we investigate ${k}^...
# 10957    we study the long range part of the \ensuremat...
# 14937    we calculate the longitudinal polarizations of...
# 19113    a model for the process ${\ensuremath{\pi}}^{+...
# ...                                                    ...
# 2031752  we obtain a model-independent expression for t...
# 2031995  we calculate the bulk viscosity due to nonequi...
# 2035163  the formulas for spin and angular correlations...
# 2037660  we use baryon chiral perturbation theory in th...
# 2043162  the polarization of quasifree \ensuremath{\lam...
#
#                                                      title publication_date  \
# 8574        σσinteractions in finite-density qcd sum rules       2008-04-14
# 9577         resonance model study onk+n→kpηnear threshold       2012-07-13
# 10957    baryon decuplet in the chiral dynamics of λ hy...       2007-03-28
# 14937    longitudinal polarization of hyperons in highp...       2002-06-12
# 19113                   resonance model forς+−k+production       1965-03-08
# ...                                                    ...              ...
# 2031752  radiative corrections to the semileptonic dali...       2002-02-28
# 2031995         bulk viscosity of superfluid hyperon stars       2008-10-14
# 2035163                             beta decay of hyperons       1971-04-01
# 2037660                           hyperon polarizabilities       1992-10-01
# 2043162  polarization of λ hyperons produced by the qua...       1992-04-01
#
#                                                   keywords  \
# 8574                                    ['finite-density']
# 9577                                                    []
# 10957           ['chiral dynamics', 'hyperons', 'nuclear']
# 14937    ['singly polarizedppcollisions', 'longitudinal...
# 19113                                            ['model']
# ...                                                    ...
# 2031752  ['semileptonic dalitz plot', 'hyperons', 'radi...
# 2031995                        ['bulk viscosity', 'stars']
# 2035163                                     ['beta decay']
# 2037660                                                 []
# 2043162                                      ['quasifree']
#
#                                                   concepts
# 8574     [('Hyperon', 0.845796), ('Quantum chromodynami...
# 9577     [('Hyperon', 0.61568487), ('Resonance (particl...
# 10957    [('Hyperon', 0.95031285), ('Physics', 0.919366...
# 14937    [('Hyperon', 0.79821134), ('Physics', 0.773141...
# 19113    [('Hyperon', 0.820969), ('Physics', 0.8052546)...
# ...                                                    ...
# 2031752  [('Hyperon', 0.95104784), ('Physics', 0.938554...
# 2031995  [('Hyperon', 0.975749), ('Physics', 0.9171221)...
# 2035163  [('Hyperon', 0.94621056), ('Physics', 0.838032...
# 2037660  [('Hyperon', 0.91110796), ('Physics', 0.896715...
# 2043162  [('Hyperon', 0.9386213), ('Physics', 0.8512599...
#
# [253 rows x 6 columns]

# %%
k = 'Physics'
df.iloc[list(sum_tree_nodes(tree[k]["leafs"]["Superconductivity"]["leafs"], visited=set())) + list(tree[k]["nodes"])]
# Out:
#                                        id  \
# 1572865  https://openalex.org/W2153625147
# 1474564  https://openalex.org/W2117192125
# 1015818  https://openalex.org/W2055778563
# 1974288  https://openalex.org/W3102829868
# 1441810  https://openalex.org/W2105172673
# ...                                   ...
# 671728   https://openalex.org/W2021652064
# 1712113  https://openalex.org/W2413005821
# 155634    https://openalex.org/W197082344
# 991221   https://openalex.org/W2053332080
# 507903   https://openalex.org/W2005459106
#
#                                                   abstract  \
# 1572865  in these lectures, a variety of non-equilibriu...
# 1474564  abstract a theoretical model describing the fo...
# 1015818  we report the effects of 200-kev ${\mathrm{he}...
# 1974288  the planckian relaxation rate $\ensuremath{\hb...
# 1441810  recent measurements of the ultrasonic at tenua...
# ...                                                    ...
# 671728   the study of β-γ circular polarization correla...
# 1712113  a reply to the comment by r. l. workman et al....
# 155634   a pole-resonance model is used to fit the data...
# 991221   we report measurements of the normal state mag...
# 507903   author(s): chupp, warren w.; goldhaber, gerson...
#
#                                                      title publication_date  \
# 1572865  collective transport in random media: from sup...       1998-07-01
# 1474564  twin spacing versus size of a monocrystal for ...       1993-08-01
# 1015818  200-kevhe+-ion irradiation effects on the prop...       1991-03-01
# 1974288  reentrant superconductivity in a quantum dot c...       2019-12-26
# 1441810  on the ultrasonic attenuation in multigap supe...       1971-06-01
# ...                                                    ...              ...
# 671728   β−γcircular polarization correlation in aj−jtr...       1957-08-15
# 1712113                                  thielet al.reply:       2013-04-19
# 155634              parameters of low-energyλ−k0production       1968-09-25
# 991221   angular dependence of thec-axis normal state m...       1996-01-01
# 507903        measurements onk-particles from the bevatron       1955-07-01
#
#                                                   keywords  \
# 1572865  ['collective transport', 'random media', 'eart...
# 1474564  ['superconductors', 'monocrystal', 'nonstoichi...
# 1015818       ['irradiation', 'pulsed-laser-depositedyba']
# 1974288  ['reentrant superconductivity', 'quantum dot',...
# 1441810                         ['ultrasonic attenuation']
# ...                                                    ...
# 671728   ['display=inline><mmlmi>β</mmlmi><mmlmo>−</mml...
# 1712113                             ['alreply', 'alreply']
# 155634                        ['parameters', 'low-energy']
# 991221    ['angular dependence', 'single crystal<mmlmath']
# 507903                                   ['onk-particles']
#
#                                                   concepts
# 1572865  [('Physics', 0.8717339), ('Superconductivity',...
# 1474564  [('Physics', 0.8272569), ('Superconductivity',...
# 1015818  [('Physics', 0.6325699), ('Superconductivity',...
# 1974288  [('Physics', 0.8672319), ('Superconductivity',...
# 1441810  [('Physics', 0.911649), ('Superconductivity', ...
# ...                                                    ...
# 671728                           [('Physics', 0.32917964)]
# 1712113                          [('Physics', 0.44117755)]
# 155634                            [('Physics', 0.4975796)]
# 991221                           [('Physics', 0.38475502)]
# 507903                           [('Physics', 0.50058603)]
#
# [4303 rows x 6 columns]

# %%
all_partitions = [list(sum_tree_nodes(tree[k]["leafs"], visited=set())) + list(tree[k]["nodes"]) for k in tqdm(tree.keys(), total=len(tree))]
# Out:
#   0%|                            | 2/21654 [00:03<10:21:40,  1.72s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 all_partitions = [list(sum_tree_nodes(tree[k]["leafs"], visited=set())) + list(tree[k]["nodes"]) for k in tqdm(tree.keys(), total=len(tree))]
#
# Cell In[19], line 1, in <listcomp>(.0)
# ----> 1 all_partitions = [list(sum_tree_nodes(tree[k]["leafs"], visited=set())) + list(tree[k]["nodes"]) for k in tqdm(tree.keys(), total=len(tree))]
#
# Cell In[14], line 5, in sum_tree_nodes(tree, visited)
#       3 for key in tree.keys():
#       4     visited = visited | tree[key]["nodes"]
# ----> 5     visited = visited | sum_tree_nodes(tree[key]["leafs"], visited)
#       7 return visited
#
# Cell In[14], line 5, in sum_tree_nodes(tree, visited)
#       3 for key in tree.keys():
#       4     visited = visited | tree[key]["nodes"]
# ----> 5     visited = visited | sum_tree_nodes(tree[key]["leafs"], visited)
#       7 return visited
#
# Cell In[14], line 5, in sum_tree_nodes(tree, visited)
#       3 for key in tree.keys():
#       4     visited = visited | tree[key]["nodes"]
# ----> 5     visited = visited | sum_tree_nodes(tree[key]["leafs"], visited)
#       7 return visited
#
# Cell In[14], line 1, in sum_tree_nodes(tree, visited)
# ----> 1 def sum_tree_nodes(tree, visited=set()):
#       3     for key in tree.keys():
#       4         visited = visited | tree[key]["nodes"]
#
# KeyboardInterrupt:

# %%
modularity(G_networkx, list(open_alex_keyword_communities_first_kw.values()), weight=None, resolution=1)

# %%
tree["Superconductivity"]
# Out:
# {'nodes': set(),
#  'leafs': {'Pairing': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Surface (topology)': {'nodes': {84}, 'leafs': {}},
#         'Charge density wave': {'nodes': {9882}, 'leafs': {}},
#         'Electron': {'nodes': {60407}, 'leafs': {}},
#         'Coulomb': {'nodes': {81717}, 'leafs': {}},
#         'Spin (aerodynamics)': {'nodes': {283450}, 'leafs': {}},
#         'Hubbard model': {'nodes': {365299}, 'leafs': {}},
#         'Phase (matter)': {'nodes': {397272}, 'leafs': {}},
#         'Observable': {'nodes': {414573}, 'leafs': {}},
#         'Singlet state': {'nodes': {450251}, 'leafs': {}},
#         'Chemistry': {'nodes': {535690}, 'leafs': {}},
#         'Anisotropy': {'nodes': {567112}, 'leafs': {}},
#         'Photoemission spectroscopy': {'nodes': {709425}, 'leafs': {}},
#         'Cooper pair': {'nodes': {793793}, 'leafs': {}},
#         'Andreev reflection': {'nodes': {829488}, 'leafs': {}},
#         'Polarizability': {'nodes': {854986}, 'leafs': {}},
#         'Electron pair': {'nodes': {878194}, 'leafs': {}},
#         'Phonon': {'nodes': {961708, 1885343}, 'leafs': {}},
#         'Organic superconductor': {'nodes': {1153481}, 'leafs': {}},
#         'Boson': {'nodes': {1188070}, 'leafs': {}},
#         'Josephson effect': {'nodes': {1228060, 1598038}, 'leafs': {}},
#         'Supercurrent': {'nodes': {1277000}, 'leafs': {}},
#         'Gapless playback': {'nodes': {1306953}, 'leafs': {}},
#         'Excitation': {'nodes': {1319961}, 'leafs': {}},
#         'Angle-resolved photoemission spectroscopy': {'nodes': {1451173},
#          'leafs': {}},
#         'Ferromagnetism': {'nodes': {1559446, 1876422}, 'leafs': {}},
#         'Electrical resistivity and conductivity': {'nodes': {1659652},
#          'leafs': {}},
#         'Copper oxide': {'nodes': {1728903}, 'leafs': {}},
#         'Liquid crystal': {'nodes': {1817445}, 'leafs': {}},
#         'Phase boundary': {'nodes': {1839106}, 'leafs': {}},
#         'Pnictogen': {'nodes': {1933785}, 'leafs': {}},
#         'Impurity': {'nodes': {2001270}, 'leafs': {}},
#         'Room-temperature superconductor': {'nodes': {2015077}, 'leafs': {}},
#         'Doping': {'nodes': {2020574}, 'leafs': {}}}},
#       'Hamiltonian (control theory)': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {24210}, 'leafs': {}},
#         'Phonon': {'nodes': {1312159}, 'leafs': {}}}},
#       'Penetration depth': {'nodes': set(),
#        'leafs': {'Doping': {'nodes': {36448}, 'leafs': {}},
#         'Superfluidity': {'nodes': {1554178}, 'leafs': {}}}},
#       'Curse of dimensionality': {'nodes': set(),
#        'leafs': {'Surface (topology)': {'nodes': {101188}, 'leafs': {}}}},
#       'Optical conductivity': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {107409}, 'leafs': {}}}},
#       'Superconducting transition temperature': {'nodes': set(),
#        'leafs': {'Kinetic isotope effect': {'nodes': {146889}, 'leafs': {}}}},
#       'Ferromagnetism': {'nodes': set(),
#        'leafs': {'Spins': {'nodes': {186471}, 'leafs': {}},
#         'Physics': {'nodes': {208518}, 'leafs': {}},
#         'Connection (principal bundle)': {'nodes': {1144365}, 'leafs': {}}}},
#       'Anisotropy': {'nodes': set(),
#        'leafs': {'Isotropy': {'nodes': {190047}, 'leafs': {}},
#         'Physics': {'nodes': {236147}, 'leafs': {}},
#         'Materials science': {'nodes': {727307}, 'leafs': {}}}},
#       'Cooper pair': {'nodes': set(),
#        'leafs': {'Amorphous solid': {'nodes': {197240}, 'leafs': {}},
#         'Mechanism (biology)': {'nodes': {1603754}, 'leafs': {}},
#         'Physics': {'nodes': {1684080}, 'leafs': {}}}},
#       'Hubbard model': {'nodes': set(),
#        'leafs': {'Oxygen': {'nodes': {235224}, 'leafs': {}}}},
#       'Impurity': {'nodes': set(),
#        'leafs': {'Neutron': {'nodes': {315021}, 'leafs': {}},
#         'Physics': {'nodes': {1365759}, 'leafs': {}}}},
#       'Magnetism': {'nodes': set(),
#        'leafs': {'Hysteresis': {'nodes': {350360}, 'leafs': {}},
#         'Ferromagnetism': {'nodes': {1820718}, 'leafs': {}}}},
#       'Surface (topology)': {'nodes': set(),
#        'leafs': {'Stacking': {'nodes': {386555}, 'leafs': {}}}},
#       'Doping': {'nodes': set(),
#        'leafs': {'Materials science': {'nodes': {428601}, 'leafs': {}},
#         'Band gap': {'nodes': {883509}, 'leafs': {}}}},
#       'Valence (chemistry)': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {442278}, 'leafs': {}}}},
#       'Scattering': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {624503}, 'leafs': {}}}},
#       'Nuclear quadrupole resonance': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {778850}, 'leafs': {}}}},
#       'Spin (aerodynamics)': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {796546}, 'leafs': {}}}},
#       'Fermi surface': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {799436, 1580920}, 'leafs': {}}}},
#       'Antiferromagnetism': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {867562, 1030931, 1089351},
#          'leafs': {}}}},
#       'Bilayer graphene': {'nodes': set(),
#        'leafs': {'Gapless playback': {'nodes': {923481}, 'leafs': {}}}},
#       'Singlet state': {'nodes': set(),
#        'leafs': {'Electron': {'nodes': {1039981}, 'leafs': {}},
#         'Specific heat': {'nodes': {1240076}, 'leafs': {}}}},
#       'Fermi gas': {'nodes': set(),
#        'leafs': {'Symmetry (geometry)': {'nodes': {1044112}, 'leafs': {}}}},
#       'Materials science': {'nodes': set(),
#        'leafs': {'High-temperature superconductivity': {'nodes': {1210224},
#          'leafs': {}}}},
#       'High-temperature superconductivity': {'nodes': set(),
#        'leafs': {'Electron': {'nodes': {1426874}, 'leafs': {}},
#         'Transition temperature': {'nodes': {1812571}, 'leafs': {}}}},
#       'Selenide': {'nodes': set(),
#        'leafs': {'Materials science': {'nodes': {1445213}, 'leafs': {}}}},
#       'Kinetic isotope effect': {'nodes': set(),
#        'leafs': {'Antiferromagnetism': {'nodes': {1621680}, 'leafs': {}}}},
#       'Cuprate': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1630746, 1710929}, 'leafs': {}}}},
#       'Limit (mathematics)': {'nodes': set(),
#        'leafs': {'Cooper pair': {'nodes': {1639828}, 'leafs': {}}}},
#       'Heterojunction': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1656810}, 'leafs': {}}}},
#       'Heat capacity': {'nodes': set(),
#        'leafs': {'Organic superconductor': {'nodes': {1662203}, 'leafs': {}}}},
#       'Residual resistivity': {'nodes': set(),
#        'leafs': {'Field (mathematics)': {'nodes': {1673021}, 'leafs': {}}}},
#       'Coupling (piping)': {'nodes': set(),
#        'leafs': {'Shape resonance': {'nodes': {1724549}, 'leafs': {}}}},
#       'Coulomb blockade': {'nodes': set(),
#        'leafs': {'Quantum tunnelling': {'nodes': {1758722}, 'leafs': {}}}},
#       'Sign (mathematics)': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1813839}, 'leafs': {}}}},
#       'Photoemission spectroscopy': {'nodes': set(),
#        'leafs': {'Spin–orbit interaction': {'nodes': {1832089}, 'leafs': {}}}},
#       'Quantum tunnelling': {'nodes': set(),
#        'leafs': {'Spectral line': {'nodes': {1873790}, 'leafs': {}}}},
#       'Instability': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1957023}, 'leafs': {}}}},
#       'Pnictogen': {'nodes': set(),
#        'leafs': {'Order (exchange)': {'nodes': {1972722}, 'leafs': {}}}},
#       'Reciprocal lattice': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1974173}, 'leafs': {}}}},
#       'Phonon': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1994700}, 'leafs': {}}}}}},
#     'Hamiltonian (control theory)': {'nodes': set(),
#      'leafs': {'Entropy (arrow of time)': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {6412}, 'leafs': {}}}},
#       'Physics': {'nodes': set(),
#        'leafs': {'Figure of merit': {'nodes': {1706795}, 'leafs': {}}}}}},
#     'Physics': {'nodes': set(),
#      'leafs': {'Coupling (piping)': {'nodes': set(),
#        'leafs': {'Electron': {'nodes': {13949}, 'leafs': {}},
#         'Spectral line': {'nodes': {503722}, 'leafs': {}},
#         'Condensed matter physics': {'nodes': {2024071}, 'leafs': {}}}},
#       'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Josephson effect': {'nodes': {28165}, 'leafs': {}},
#         'Coupling (piping)': {'nodes': {254032}, 'leafs': {}},
#         'Coulomb': {'nodes': {465234, 889184}, 'leafs': {}},
#         'Attraction': {'nodes': {553082}, 'leafs': {}},
#         'BCS theory': {'nodes': {769410}, 'leafs': {}},
#         'Local density of states': {'nodes': {796274}, 'leafs': {}},
#         'London penetration depth': {'nodes': {811253}, 'leafs': {}},
#         'Coupling constant': {'nodes': {1232039}, 'leafs': {}},
#         'Coherence (philosophical gambling strategy)': {'nodes': {1369146},
#          'leafs': {}},
#         'Phonon': {'nodes': {1392850}, 'leafs': {}},
#         'Materials science': {'nodes': {1490228}, 'leafs': {}},
#         'Quasiparticle': {'nodes': {1563036}, 'leafs': {}},
#         'Penetration depth': {'nodes': {1670810}, 'leafs': {}},
#         'Inelastic neutron scattering': {'nodes': {1764761}, 'leafs': {}},
#         'Boundary (topology)': {'nodes': {1778883}, 'leafs': {}},
#         'Limiting': {'nodes': {1817595}, 'leafs': {}},
#         'Critical field': {'nodes': {1837777}, 'leafs': {}},
#         'Ginzburg–Landau theory': {'nodes': {1867945}, 'leafs': {}},
#         'Lattice (music)': {'nodes': {1891230}, 'leafs': {}},
#         'Sign (mathematics)': {'nodes': {1916559}, 'leafs': {}}}},
#       'Symmetry (geometry)': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {39951}, 'leafs': {}}}},
#       'Scattering': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {42729}, 'leafs': {}}}},
#       'Hubbard model': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {348101},
#          'leafs': {}}}},
#       'Coulomb': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {386519},
#          'leafs': {}}}},
#       'Quasiparticle': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {441715}, 'leafs': {}},
#         'Cuprate': {'nodes': {915691}, 'leafs': {}}}},
#       'Vertex (graph theory)': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {489585},
#          'leafs': {}}}},
#       'Electromagnetic shielding': {'nodes': set(),
#        'leafs': {'Doping': {'nodes': {498528}, 'leafs': {}}}},
#       'Isotropy': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1017649},
#          'leafs': {}}}},
#       'Andreev reflection': {'nodes': set(),
#        'leafs': {'Symmetry (geometry)': {'nodes': {1256700}, 'leafs': {}}}},
#       'Bound state': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1422924},
#          'leafs': {}}}},
#       'Phonon': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1454541},
#          'leafs': {}}}},
#       'Quantum tunnelling': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1582337},
#          'leafs': {}}}},
#       'Quantum critical point': {'nodes': set(),
#        'leafs': {'Critical point (mathematics)': {'nodes': {1600191},
#          'leafs': {}}}},
#       'Transverse plane': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1614919},
#          'leafs': {}}}},
#       'Optical conductivity': {'nodes': set(),
#        'leafs': {'Coupling (piping)': {'nodes': {1644893}, 'leafs': {}}}},
#       'Conductor': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1674115},
#          'leafs': {}}}},
#       'Atomic orbital': {'nodes': set(),
#        'leafs': {'Oxygen': {'nodes': {1727482}, 'leafs': {}}}},
#       'Topology (electrical circuits)': {'nodes': set(),
#        'leafs': {'Lambda': {'nodes': {1729066}, 'leafs': {}}}},
#       'Component (thermodynamics)': {'nodes': set(),
#        'leafs': {'Fermion': {'nodes': {1800396}, 'leafs': {}}}},
#       'Bilayer graphene': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1942789},
#          'leafs': {}}}}}},
#     'Pnictogen': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {14832}, 'leafs': {}}}}}},
#     'Monolayer': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {27735},
#          'leafs': {}}}}}},
#     'Phonon': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {28763}, 'leafs': {}},
#         'Kinetic isotope effect': {'nodes': {1706809}, 'leafs': {}}}}}},
#     'Hubbard model': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {75697}, 'leafs': {}}}},
#       'Tight binding': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1808894}, 'leafs': {}}}}}},
#     'Superfluidity': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Cuprate': {'nodes': {166402}, 'leafs': {}}}},
#       'Physics': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {760604},
#          'leafs': {}}}}}},
#     'Ferromagnetism': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {334969, 1661617},
#          'leafs': {}}}},
#       'Multiplet': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {485985}, 'leafs': {}}}}}},
#     'Scattering': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Function (biology)': {'nodes': {354743}, 'leafs': {}}}}}},
#     'Heat capacity': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Phase diagram': {'nodes': {405865}, 'leafs': {}}}}}},
#     'Raman spectroscopy': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Raman scattering': {'nodes': {430500}, 'leafs': {}}}},
#       'Spectral line': {'nodes': set(),
#        'leafs': {'Planar': {'nodes': {637944}, 'leafs': {}}}},
#       'Cuprate': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1525263},
#          'leafs': {}}}}}},
#     'Vortex': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {444563},
#          'leafs': {}}}}}},
#     'Fermi surface': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {458499},
#          'leafs': {}}}},
#       'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Magnitude (astronomy)': {'nodes': {1121534}, 'leafs': {}},
#         'Anisotropy': {'nodes': {1876870}, 'leafs': {}}}}}},
#     'Antiferromagnetism': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Spin (aerodynamics)': {'nodes': {521667}, 'leafs': {}},
#         'Tetragonal crystal system': {'nodes': {973002}, 'leafs': {}},
#         'Physics': {'nodes': {1084507, 2000878}, 'leafs': {}},
#         'Heavy fermion': {'nodes': {1319041}, 'leafs': {}}}}}},
#     'Character (mathematics)': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Energy (signal processing)': {'nodes': {582769},
#          'leafs': {}}}}}},
#     'BCS theory': {'nodes': set(),
#      'leafs': {'Cuprate': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {606628},
#          'leafs': {}}}}}},
#     'Coulomb': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Scaling': {'nodes': {613391}, 'leafs': {}}}}}},
#     'Knight shift': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Singlet state': {'nodes': {658933}, 'leafs': {}},
#         'Heavy fermion superconductor': {'nodes': {755640}, 'leafs': {}}}}}},
#     'Phase diagram': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {706260}, 'leafs': {}}}}}},
#     'Electron': {'nodes': set(),
#      'leafs': {'Cuprate': {'nodes': set(),
#        'leafs': {'Electron pair': {'nodes': {726173}, 'leafs': {}}}},
#       'Momentum (technical analysis)': {'nodes': set(),
#        'leafs': {'Annihilation': {'nodes': {1020119}, 'leafs': {}}}},
#       'Physics': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1681102},
#          'leafs': {}}}}}},
#     'Inelastic neutron scattering': {'nodes': set(),
#      'leafs': {'Phonon': {'nodes': set(),
#        'leafs': {'Degenerate energy levels': {'nodes': {727944},
#          'leafs': {}}}}}},
#     'Analogy': {'nodes': set(),
#      'leafs': {'Symmetry (geometry)': {'nodes': set(),
#        'leafs': {'Bent molecular geometry': {'nodes': {794790},
#          'leafs': {}}}}}},
#     'Cuprate': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Scanning tunneling microscope': {'nodes': {864785},
#          'leafs': {}},
#         'High-temperature superconductivity': {'nodes': {1141042},
#          'leafs': {}},
#         'Symmetry (geometry)': {'nodes': {1963396}, 'leafs': {}}}},
#       'Physics': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {901135},
#          'leafs': {}}}},
#       'Odds': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1126309},
#          'leafs': {}}}},
#       'Antibonding molecular orbital': {'nodes': set(),
#        'leafs': {'Doping': {'nodes': {1632494}, 'leafs': {}}}},
#       'Atomic orbital': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1752789},
#          'leafs': {}}}}}},
#     'Mesoscopic physics': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'BCS theory': {'nodes': {927121}, 'leafs': {}}}}}},
#     'Specific heat': {'nodes': set(),
#      'leafs': {'Arc melting': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {980706},
#          'leafs': {}}}}}},
#     'Conductance': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {986441}, 'leafs': {}}}}}},
#     'Isostructural': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Diamond': {'nodes': {1015813}, 'leafs': {}}}}}},
#     'Quasiparticle': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1084430}, 'leafs': {}}}},
#       'Physics': {'nodes': set(),
#        'leafs': {'Cooper pair': {'nodes': {1965672}, 'leafs': {}}}}}},
#     'Impurity': {'nodes': set(),
#      'leafs': {'Anderson impurity model': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1109179},
#          'leafs': {}}}}}},
#     'Symmetry (geometry)': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1112216}, 'leafs': {}}}}}},
#     'Formalism (music)': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1145270, 1847793}, 'leafs': {}}}}}},
#     'Magnetism': {'nodes': set(),
#      'leafs': {'Electron pair': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1201200},
#          'leafs': {}}}},
#       'Theoretical physics': {'nodes': set(),
#        'leafs': {'Symmetry (geometry)': {'nodes': {1916963}, 'leafs': {}}}},
#       'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1940867}, 'leafs': {}}}}}},
#     'Proximity effect (electron beam lithography)': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1204990},
#          'leafs': {}}}}}},
#     'Anisotropy': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Penetration depth': {'nodes': {1292358}, 'leafs': {}},
#         'Formalism (music)': {'nodes': {1839465}, 'leafs': {}}}}}},
#     'Context (archaeology)': {'nodes': set(),
#      'leafs': {'Antiferromagnetism': {'nodes': set(),
#        'leafs': {'Heavy fermion': {'nodes': {1376548}, 'leafs': {}}}}}},
#     'Current (fluid)': {'nodes': set(),
#      'leafs': {'Order (exchange)': {'nodes': set(),
#        'leafs': {'Theoretical physics': {'nodes': {1394183}, 'leafs': {}}}}}},
#     'Coupling (piping)': {'nodes': set(),
#      'leafs': {'Materials science': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1625146},
#          'leafs': {}}}}}},
#     'Instability': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1640090}, 'leafs': {}}}}}},
#     'Heavy fermion': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1691080},
#          'leafs': {}}}}}},
#     'Topological insulator': {'nodes': set(),
#      'leafs': {'MAJORANA': {'nodes': set(),
#        'leafs': {'Topology (electrical circuits)': {'nodes': {1791142},
#          'leafs': {}}}}}},
#     'Chalcogenide': {'nodes': set(),
#      'leafs': {'Materials science': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1806357},
#          'leafs': {}}}}}},
#     'Topology (electrical circuits)': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Fermi level': {'nodes': {1833415}, 'leafs': {}}}}}},
#     'Muon spin spectroscopy': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Cuprate': {'nodes': {1839282}, 'leafs': {}}}}}},
#     'London penetration depth': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Topological insulator': {'nodes': {1887572},
#          'leafs': {}}}}}},
#     'Cooper pair': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1892580}, 'leafs': {}}}}}},
#     'Photoemission spectroscopy': {'nodes': set(),
#      'leafs': {'Topology (electrical circuits)': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1939830},
#          'leafs': {}}}}}},
#     'Graphene': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Scanning tunneling microscope': {'nodes': {1975028},
#          'leafs': {}}}}}},
#     'Scanning tunneling microscope': {'nodes': set(),
#      'leafs': {'Scanning tunneling spectroscopy': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {2013268},
#          'leafs': {}}}}}},
#     'Intermetallic': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Quantum tunnelling': {'nodes': {2025634}, 'leafs': {}}}}}}}},
#   'Physics': {'nodes': set(),
#    'leafs': {'Alkali metal': {'nodes': set(),
#      'leafs': {'Cuprate': {'nodes': set(),
#        'leafs': {'Fullerene': {'nodes': {246}, 'leafs': {}}}},
#       'Crystallography': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {45440},
#          'leafs': {}}}}}},
#     'Critical field': {'nodes': set(),
#      'leafs': {'Coupling (piping)': {'nodes': set(),
#        'leafs': {'Ternary operation': {'nodes': {329}, 'leafs': {}}}},
#       'Fermi level': {'nodes': set(),
#        'leafs': {'Type (biology)': {'nodes': {56425}, 'leafs': {}}}},
#       'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Tunnel diode': {'nodes': {63253}, 'leafs': {}},
#         'Magnetic field': {'nodes': {472545, 591944}, 'leafs': {}},
#         'Alkali metal': {'nodes': {752217}, 'leafs': {}},
#         'Bismuth': {'nodes': {1772190}, 'leafs': {}}}},
#       'Energy (signal processing)': {'nodes': set(),
#        'leafs': {'Field (mathematics)': {'nodes': {281983}, 'leafs': {}}}},
#       'Molybdenum': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1063708},
#          'leafs': {}}}},
#       'London penetration depth': {'nodes': set(),
#        'leafs': {'Penetration depth': {'nodes': {2045013}, 'leafs': {}}}}}},
#     'Impurity': {'nodes': set(),
#      'leafs': {'Charge (physics)': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {519}, 'leafs': {}}}},
#       'Quasiparticle': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {67987}, 'leafs': {}}}},
#       'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Order (exchange)': {'nodes': {1179949}, 'leafs': {}}}}}},
#     'Condensed matter physics': {'nodes': {14723,
#       34495,
#       82236,
#       130118,
#       161241,
#       213441,
#       224328,
#       289114,
#       307186,
#       476014,
#       476393,
#       631122,
#       641676,
#       662201,
#       734235,
#       780762,
#       813660,
#       823538,
#       875673,
#       893441,
#       962023,
#       969462,
#       978929,
#       1004535,
#       1024399,
#       1210781,
#       1380290,
#       1574873,
#       1607120,
#       1685468,
#       1695696,
#       1705029,
#       1771253,
#       1779610,
#       1967232,
#       2022887},
#      'leafs': {'Charge (physics)': {'nodes': set(),
#        'leafs': {'Cuprate': {'nodes': {569, 949037}, 'leafs': {}},
#         'Crystallography': {'nodes': {50372}, 'leafs': {}},
#         'Magnetization': {'nodes': {1091524}, 'leafs': {}},
#         'London penetration depth': {'nodes': {1729204}, 'leafs': {}},
#         'Electron': {'nodes': {2009695}, 'leafs': {}}}},
#       'Orthorhombic crystal system': {'nodes': set(),
#        'leafs': {'Rietveld refinement': {'nodes': {1893}, 'leafs': {}},
#         'Muon spin spectroscopy': {'nodes': {1844633}, 'leafs': {}}}},
#       'Electrical resistivity and conductivity': {'nodes': set(),
#        'leafs': {'Phase transition': {'nodes': {3250}, 'leafs': {}},
#         'Field (mathematics)': {'nodes': {43095}, 'leafs': {}},
#         'Fermi liquid theory': {'nodes': {55966}, 'leafs': {}},
#         'Germanium': {'nodes': {320611}, 'leafs': {}},
#         'Order (exchange)': {'nodes': {356912}, 'leafs': {}},
#         'Superconducting coherence length': {'nodes': {426437}, 'leafs': {}},
#         'Prime (order theory)': {'nodes': {718943}, 'leafs': {}},
#         'Materials science': {'nodes': {955898}, 'leafs': {}},
#         'Crystallography': {'nodes': {1281363}, 'leafs': {}},
#         'Critical field': {'nodes': {1768793}, 'leafs': {}},
#         'Coherence length': {'nodes': {1798044}, 'leafs': {}},
#         'Skutterudite': {'nodes': {1828986}, 'leafs': {}}}},
#       'Phonon': {'nodes': set(),
#        'leafs': {'Charge density wave': {'nodes': {6812, 1248028},
#          'leafs': {}},
#         'Coupling (piping)': {'nodes': {110720}, 'leafs': {}},
#         'Scattering': {'nodes': {439044}, 'leafs': {}},
#         'Electrical resistivity and conductivity': {'nodes': {498319},
#          'leafs': {}},
#         'Moment (physics)': {'nodes': {705410}, 'leafs': {}},
#         'Quasiparticle': {'nodes': {1402054}, 'leafs': {}},
#         'Energy (signal processing)': {'nodes': {1570662}, 'leafs': {}},
#         'Electronic band structure': {'nodes': {1778113}, 'leafs': {}},
#         'Inelastic neutron scattering': {'nodes': {1825027}, 'leafs': {}},
#         'Order (exchange)': {'nodes': {1883461}, 'leafs': {}}}},
#       'Chirality (physics)': {'nodes': set(),
#        'leafs': {'Dirac (video compression format)': {'nodes': {8399},
#          'leafs': {}}}},
#       'Lambda': {'nodes': set(),
#        'leafs': {'Penetration depth': {'nodes': {8774, 1095106}, 'leafs': {}},
#         'Anisotropy': {'nodes': {878365}, 'leafs': {}}}},
#       'Energy (signal processing)': {'nodes': set(),
#        'leafs': {'Scaling': {'nodes': {12527}, 'leafs': {}},
#         'Variational Monte Carlo': {'nodes': {225838}, 'leafs': {}},
#         'Doping': {'nodes': {245000}, 'leafs': {}},
#         'Quantum tunnelling': {'nodes': {338246, 1468343}, 'leafs': {}},
#         'Type (biology)': {'nodes': {477545}, 'leafs': {}},
#         'Quantum mechanics': {'nodes': {796136}, 'leafs': {}},
#         'Electrical resistivity and conductivity': {'nodes': {1728063},
#          'leafs': {}},
#         'Materials science': {'nodes': {1837480}, 'leafs': {}}}},
#       'Magnetism': {'nodes': set(),
#        'leafs': {'Ferromagnetism': {'nodes': {13906}, 'leafs': {}},
#         'Anisotropy': {'nodes': {75091}, 'leafs': {}},
#         'Symmetry breaking': {'nodes': {505734}, 'leafs': {}}}},
#       'Heat capacity': {'nodes': set(),
#        'leafs': {'Band gap': {'nodes': {19006}, 'leafs': {}},
#         'Type (biology)': {'nodes': {1241449}, 'leafs': {}}}},
#       'Coupling (piping)': {'nodes': set(),
#        'leafs': {'Doping': {'nodes': {19715}, 'leafs': {}},
#         'Crystallography': {'nodes': {20210, 55354}, 'leafs': {}},
#         'Materials science': {'nodes': {45611, 122268, 1764447, 1897947},
#          'leafs': {}},
#         'Type (biology)': {'nodes': {143850}, 'leafs': {}},
#         'Impurity': {'nodes': {395207}, 'leafs': {}},
#         'Phonon': {'nodes': {650344, 1131463, 1895223}, 'leafs': {}},
#         'Germanium': {'nodes': {951091}, 'leafs': {}},
#         'Coherence length': {'nodes': {1047340}, 'leafs': {}},
#         'Anisotropy': {'nodes': {1285499}, 'leafs': {}},
#         'Order (exchange)': {'nodes': {1539957}, 'leafs': {}},
#         'Antiferromagnetism': {'nodes': {1713874}, 'leafs': {}}}},
#       'Crystallography': {'nodes': set(),
#        'leafs': {'Materials science': {'nodes': {19940,
#           655091,
#           1687102,
#           1709543,
#           1841534},
#          'leafs': {}},
#         'Chemistry': {'nodes': {38838, 44204, 48304, 983703, 1882243, 1903197},
#          'leafs': {}},
#         'Ternary operation': {'nodes': {1391079}, 'leafs': {}},
#         'Magnetic moment': {'nodes': {1586673}, 'leafs': {}},
#         'Critical field': {'nodes': {1675810, 1717327, 1956607}, 'leafs': {}},
#         'Phase (matter)': {'nodes': {1848706}, 'leafs': {}},
#         'Energy (signal processing)': {'nodes': {2026063}, 'leafs': {}}}},
#       'Magnetic flux quantum': {'nodes': set(),
#        'leafs': {'Cooper pair': {'nodes': {22482}, 'leafs': {}},
#         'Holography': {'nodes': {477432}, 'leafs': {}}}},
#       'Spin density wave': {'nodes': set(),
#        'leafs': {'Symmetry (geometry)': {'nodes': {24793}, 'leafs': {}},
#         'BCS theory': {'nodes': {422233}, 'leafs': {}}}},
#       'Symmetry breaking': {'nodes': set(),
#        'leafs': {'Magnetization': {'nodes': {25368}, 'leafs': {}}}},
#       'Cylinder': {'nodes': set(),
#        'leafs': {'Axial symmetry': {'nodes': {28345}, 'leafs': {}}}},
#       'Nuclear magnetic resonance': {'nodes': {28646}, 'leafs': {}},
#       'Delocalized electron': {'nodes': set(),
#        'leafs': {'Density of states': {'nodes': {30189}, 'leafs': {}}}},
#       'Pulsed laser deposition': {'nodes': set(),
#        'leafs': {'Superconducting transition temperature': {'nodes': {32537},
#          'leafs': {}}}},
#       'Photoemission spectroscopy': {'nodes': set(),
#        'leafs': {'Coupling (piping)': {'nodes': {32728}, 'leafs': {}}}},
#       'Cuprate': {'nodes': set(),
#        'leafs': {'Vortex': {'nodes': {37247}, 'leafs': {}},
#         'Omega': {'nodes': {422092}, 'leafs': {}},
#         'Chalcogenide': {'nodes': {576054}, 'leafs': {}},
#         'Coherence length': {'nodes': {1181146}, 'leafs': {}}}},
#       'Crystallite': {'nodes': set(),
#        'leafs': {'Scaling': {'nodes': {39148}, 'leafs': {}},
#         'Context (archaeology)': {'nodes': {54624}, 'leafs': {}}}},
#       'Quasiparticle': {'nodes': set(),
#        'leafs': {'Coulomb': {'nodes': {39437}, 'leafs': {}},
#         'Cuprate': {'nodes': {216045}, 'leafs': {}},
#         'Boltzmann equation': {'nodes': {263413}, 'leafs': {}},
#         'Mesoscopic physics': {'nodes': {515598}, 'leafs': {}},
#         'Penetration depth': {'nodes': {603631}, 'leafs': {}},
#         'Anisotropy': {'nodes': {1008125}, 'leafs': {}},
#         'Scattering': {'nodes': {1031882}, 'leafs': {}},
#         'Mott insulator': {'nodes': {1124972}, 'leafs': {}},
#         'Seebeck coefficient': {'nodes': {1733281}, 'leafs': {}},
#         'Superfluidity': {'nodes': {1823640}, 'leafs': {}},
#         'Orientation (vector space)': {'nodes': {1909583}, 'leafs': {}},
#         'Pairing': {'nodes': {1931574}, 'leafs': {}}}},
#       'Order (exchange)': {'nodes': set(),
#        'leafs': {'Microwave': {'nodes': {39542}, 'leafs': {}},
#         'Pairing': {'nodes': {51682}, 'leafs': {}},
#         'Mean free path': {'nodes': {369185}, 'leafs': {}},
#         'Magnetic field': {'nodes': {388808}, 'leafs': {}},
#         'Economics': {'nodes': {1231671}, 'leafs': {}},
#         'Energy (signal processing)': {'nodes': {1679817}, 'leafs': {}},
#         'Phase transition': {'nodes': {1792111}, 'leafs': {}},
#         'Critical field': {'nodes': {1968914}, 'leafs': {}},
#         'Homogeneous space': {'nodes': {2022209}, 'leafs': {}}}},
#       'Crystal (programming language)': {'nodes': set(),
#        'leafs': {'Ferromagnetism': {'nodes': {41591}, 'leafs': {}}}},
#       'Metastability': {'nodes': set(),
#        'leafs': {'Relaxation (psychology)': {'nodes': {41941}, 'leafs': {}}}},
#       'Cooper pair': {'nodes': set(),
#        'leafs': {'Symmetry breaking': {'nodes': {41980}, 'leafs': {}},
#         'Diamagnetism': {'nodes': {1307578}, 'leafs': {}},
#         'Granularity': {'nodes': {1954412}, 'leafs': {}}}},
#       'Magnetic moment': {'nodes': set(),
#        'leafs': {'Crystallography': {'nodes': {42071}, 'leafs': {}},
#         'Electron energy loss spectroscopy': {'nodes': {504926}, 'leafs': {}},
#         'Electron': {'nodes': {891587}, 'leafs': {}}}},
#       'Electronic structure': {'nodes': set(),
#        'leafs': {'Energy (signal processing)': {'nodes': {42874},
#          'leafs': {}}}},
#       'Magnetization': {'nodes': set(),
#        'leafs': {'Lattice (music)': {'nodes': {43615}, 'leafs': {}},
#         'Flux (metallurgy)': {'nodes': {48889}, 'leafs': {}},
#         'Phase transition': {'nodes': {49951}, 'leafs': {}},
#         'Saturation (graph theory)': {'nodes': {319463}, 'leafs': {}},
#         'Field (mathematics)': {'nodes': {1094494}, 'leafs': {}},
#         'Critical field': {'nodes': {1706320}, 'leafs': {}},
#         'Electrical resistivity and conductivity': {'nodes': {1787236},
#          'leafs': {}}}},
#       'Impurity': {'nodes': set(),
#        'leafs': {'Electrical resistivity and conductivity': {'nodes': {43642},
#          'leafs': {}},
#         'Thermal conduction': {'nodes': {1301302}, 'leafs': {}},
#         'Symmetry (geometry)': {'nodes': {1637867}, 'leafs': {}},
#         'Scattering': {'nodes': {2046939}, 'leafs': {}}}},
#       'Skutterudite': {'nodes': set(),
#        'leafs': {'Debye model': {'nodes': {45966}, 'leafs': {}}}},
#       'Density of states': {'nodes': set(),
#        'leafs': {'Impurity': {'nodes': {46317}, 'leafs': {}},
#         'Spectroscopy': {'nodes': {1666670}, 'leafs': {}}}},
#       'Spectral density': {'nodes': set(),
#        'leafs': {'Fourier transform': {'nodes': {47020}, 'leafs': {}}}},
#       'Anisotropy': {'nodes': set(),
#        'leafs': {'Line (geometry)': {'nodes': {47836}, 'leafs': {}},
#         'Fermi surface': {'nodes': {57923}, 'leafs': {}},
#         'Meissner effect': {'nodes': {698961}, 'leafs': {}},
#         'Crossover': {'nodes': {809536}, 'leafs': {}},
#         'Josephson effect': {'nodes': {918341}, 'leafs': {}},
#         'Spectroscopy': {'nodes': {1057035}, 'leafs': {}},
#         'Order (exchange)': {'nodes': {1090432, 1386604}, 'leafs': {}},
#         'Crystal (programming language)': {'nodes': {1143230}, 'leafs': {}},
#         'Critical field': {'nodes': {1238952}, 'leafs': {}},
#         'Sigma': {'nodes': {1346327}, 'leafs': {}},
#         'Electrical resistivity and conductivity': {'nodes': {1363946,
#           1699625},
#          'leafs': {}},
#         'Homogeneous space': {'nodes': {1569887}, 'leafs': {}},
#         'Coherence length': {'nodes': {1611901}, 'leafs': {}},
#         'Doping': {'nodes': {1655589}, 'leafs': {}},
#         'Quantum mechanics': {'nodes': {1828782}, 'leafs': {}},
#         'Materials science': {'nodes': {1917274}, 'leafs': {}}}},
#       'Antibonding molecular orbital': {'nodes': set(),
#        'leafs': {'Quantum mechanics': {'nodes': {47945}, 'leafs': {}}}},
#       'Noise (video)': {'nodes': set(),
#        'leafs': {'Crystallography': {'nodes': {52970}, 'leafs': {}}}},
#       'Conductance': {'nodes': set(),
#        'leafs': {'Quantum tunnelling': {'nodes': {53357}, 'leafs': {}},
#         'Quantum dot': {'nodes': {1573136}, 'leafs': {}}}},
#       'Magnetic field': {'nodes': set(),
#        'leafs': {'Anomaly (physics)': {'nodes': {53788}, 'leafs': {}},
#         'Topology (electrical circuits)': {'nodes': {72014}, 'leafs': {}},
#         'Critical field': {'nodes': {246955}, 'leafs': {}},
#         'Crystal (programming language)': {'nodes': {613938}, 'leafs': {}},
#         'London penetration depth': {'nodes': {971710}, 'leafs': {}},
#         'Symmetry (geometry)': {'nodes': {1119415}, 'leafs': {}},
#         'Holography': {'nodes': {1159779}, 'leafs': {}},
#         'Conductor': {'nodes': {1508658, 1816016}, 'leafs': {}},
#         'Magnetization': {'nodes': {1602921}, 'leafs': {}}}},
#       'Transverse plane': {'nodes': set(),
#        'leafs': {'Phonon': {'nodes': {53792}, 'leafs': {}}}},
#       'Bilayer': {'nodes': set(),
#        'leafs': {'Coupling (piping)': {'nodes': {54833}, 'leafs': {}}}},
#       'Van Hove singularity': {'nodes': set(),
#        'leafs': {'Isostructural': {'nodes': {55895}, 'leafs': {}}}},
#       'Spin (aerodynamics)': {'nodes': set(),
#        'leafs': {'Coupling (piping)': {'nodes': {56378}, 'leafs': {}},
#         'Lattice (music)': {'nodes': {1240561}, 'leafs': {}},
#         'High pressure': {'nodes': {1850466}, 'leafs': {}},
#         'Nuclear magnetic resonance': {'nodes': {2043967}, 'leafs': {}}}},
#       'Electron': {'nodes': set(),
#        'leafs': {'Uncorrelated': {'nodes': {57650}, 'leafs': {}},
#         'Valence (chemistry)': {'nodes': {429425}, 'leafs': {}},
#         'Coupling (piping)': {'nodes': {872076}, 'leafs': {}},
#         'Specific heat': {'nodes': {909254}, 'leafs': {}},
#         'Boson': {'nodes': {939264}, 'leafs': {}},
#         'Spin (aerodynamics)': {'nodes': {972277}, 'leafs': {}}}},
#       'Fermi surface': {'nodes': set(),
#        'leafs': {'Magnetoresistance': {'nodes': {61743}, 'leafs': {}},
#         'State (computer science)': {'nodes': {407124}, 'leafs': {}},
#         'Scattering': {'nodes': {700728}, 'leafs': {}},
#         'Anisotropy': {'nodes': {1033541}, 'leafs': {}},
#         'Electronic structure': {'nodes': {1182209}, 'leafs': {}},
#         'Decoupling (probability)': {'nodes': {1335083}, 'leafs': {}},
#         'Electrical resistivity and conductivity': {'nodes': {1363971},
#          'leafs': {}},
#         'Scaling': {'nodes': {1815919}, 'leafs': {}}}},
#       'Phase diagram': {'nodes': set(),
#        'leafs': {'Superconducting wire': {'nodes': {61861}, 'leafs': {}},
#         'Hubbard model': {'nodes': {283034}, 'leafs': {}},
#         'Antiferromagnetism': {'nodes': {488592}, 'leafs': {}},
#         'Order (exchange)': {'nodes': {1119349, 1226395}, 'leafs': {}},
#         'Quantum critical point': {'nodes': {1631558}, 'leafs': {}},
#         'Paramagnetism': {'nodes': {1767487}, 'leafs': {}},
#         'Orbit (dynamics)': {'nodes': {1796718}, 'leafs': {}},
#         'Electron': {'nodes': {1806257}, 'leafs': {}},
#         'Energy (signal processing)': {'nodes': {1865671}, 'leafs': {}},
#         'Pairing': {'nodes': {1884276}, 'leafs': {}}}},
#       'Dimensionless quantity': {'nodes': set(),
#        'leafs': {'Antiferromagnetism': {'nodes': {63605}, 'leafs': {}}}},
#       'Ab initio': {'nodes': set(),
#        'leafs': {'Anisotropy': {'nodes': {65665}, 'leafs': {}},
#         'Energy (signal processing)': {'nodes': {774028}, 'leafs': {}}}},
#       'Tetragonal crystal system': {'nodes': set(),
#        'leafs': {'Anisotropy': {'nodes': {68328}, 'leafs': {}},
#         'Specific heat': {'nodes': {247765}, 'leafs': {}},
#         'Transition temperature': {'nodes': {993536}, 'leafs': {}},
#         'Crystallography': {'nodes': {1549413}, 'leafs': {}}}},
#       'Infrared': {'nodes': set(),
#        'leafs': {'Field (mathematics)': {'nodes': {72727}, 'leafs': {}},
#         'Order (exchange)': {'nodes': {380570}, 'leafs': {}}}},
#       'Ground state': {'nodes': set(),
#        'leafs': {'Ternary operation': {'nodes': {73541}, 'leafs': {}},
#         'Electrical resistivity and conductivity': {'nodes': {1802918},
#          'leafs': {}}}},
#       'Coherence (philosophical gambling strategy)': {'nodes': set(),
#        'leafs': {'Inverse': {'nodes': {77943}, 'leafs': {}}}},
#       'Doping': {'nodes': set(),
#        'leafs': {'Oxygen': {'nodes': {82017}, 'leafs': {}},
#         'Metal': {'nodes': {454618}, 'leafs': {}},
#         'Pairing': {'nodes': {525473}, 'leafs': {}},
#         'Band gap': {'nodes': {722172}, 'leafs': {}},
#         'Fermi level': {'nodes': {811585}, 'leafs': {}},
#         'Extension (predicate logic)': {'nodes': {1557946}, 'leafs': {}},
#         'Transition temperature': {'nodes': {1905035}, 'leafs': {}},
#         'Anisotropy': {'nodes': {1955236}, 'leafs': {}}}},
#       'Electronic band structure': {'nodes': set(),
#        'leafs': {'Fermi level': {'nodes': {82090, 1290304}, 'leafs': {}}}},
#       'Insulator (electricity)': {'nodes': set(),
#        'leafs': {'Tunnel junction': {'nodes': {83156}, 'leafs': {}}}},
#       'Effective mass (spring–mass system)': {'nodes': set(),
#        'leafs': {'Electrical resistivity and conductivity': {'nodes': {91764},
#          'leafs': {}}}},
#       'Vortex': {'nodes': set(),
#        'leafs': {'Antiferromagnetism': {'nodes': {93002}, 'leafs': {}},
#         'Hexagonal lattice': {'nodes': {240093}, 'leafs': {}},
#         'Critical current': {'nodes': {340581}, 'leafs': {}},
#         'Coupling (piping)': {'nodes': {427029}, 'leafs': {}},
#         'Stochastic dynamics': {'nodes': {470477}, 'leafs': {}},
#         'Adiabatic process': {'nodes': {873181}, 'leafs': {}},
#         'Cuprate': {'nodes': {1400309}, 'leafs': {}},
#         'Type-II superconductor': {'nodes': {1459913}, 'leafs': {}},
#         'Phase (matter)': {'nodes': {1752837}, 'leafs': {}},
#         'Cooper pair': {'nodes': {1942899}, 'leafs': {}}}},
#       'Valence (chemistry)': {'nodes': set(),
#        'leafs': {'Valence bond theory': {'nodes': {93929}, 'leafs': {}},
#         'Flux (metallurgy)': {'nodes': {612255}, 'leafs': {}}}},
#       'Curvature': {'nodes': set(),
#        'leafs': {'Magnetic field': {'nodes': {104103}, 'leafs': {}}}},
#       'Metal': {'nodes': set(),
#        'leafs': {'Simple (philosophy)': {'nodes': {107138}, 'leafs': {}},
#         'Materials science': {'nodes': {961099}, 'leafs': {}}}},
#       'London penetration depth': {'nodes': set(),
#        'leafs': {'Superfluidity': {'nodes': {108430}, 'leafs': {}},
#         'Coherence length': {'nodes': {569758}, 'leafs': {}},
#         'Critical field': {'nodes': {997203}, 'leafs': {}},
#         'Crystallography': {'nodes': {1304619}, 'leafs': {}},
#         'Materials science': {'nodes': {1914681}, 'leafs': {}}}},
#       'Parity (physics)': {'nodes': set(),
#        'leafs': {'Conductor': {'nodes': {115264}, 'leafs': {}}}},
#       'Quantum tunnelling': {'nodes': set(),
#        'leafs': {'Magnetic field': {'nodes': {118009}, 'leafs': {}},
#         'Phonon': {'nodes': {325764}, 'leafs': {}},
#         'Thermal fluctuations': {'nodes': {714066}, 'leafs': {}},
#         'Conductance': {'nodes': {1767025}, 'leafs': {}}}},
#       'Crossover': {'nodes': set(),
#        'leafs': {'Zero (linguistics)': {'nodes': {118462}, 'leafs': {}},
#         'Lattice (music)': {'nodes': {1803300}, 'leafs': {}}}},
#       'Scattering': {'nodes': set(),
#        'leafs': {'Pairing': {'nodes': {136874, 1945358}, 'leafs': {}},
#         'Omega': {'nodes': {266534}, 'leafs': {}},
#         'Anisotropy': {'nodes': {385452}, 'leafs': {}},
#         'Momentum (technical analysis)': {'nodes': {696832}, 'leafs': {}},
#         'Neutron scattering': {'nodes': {1103391}, 'leafs': {}},
#         'Order (exchange)': {'nodes': {1128671}, 'leafs': {}},
#         'Vortex': {'nodes': {1154101}, 'leafs': {}},
#         'Resonance (particle physics)': {'nodes': {1225630}, 'leafs': {}},
#         'Coherence length': {'nodes': {1786850}, 'leafs': {}}}},
#       'Field (mathematics)': {'nodes': set(),
#        'leafs': {'Ampere': {'nodes': {136945}, 'leafs': {}},
#         'Magnetic field': {'nodes': {894427}, 'leafs': {}},
#         'Plane (geometry)': {'nodes': {1010784}, 'leafs': {}},
#         'Specific heat': {'nodes': {1238652}, 'leafs': {}},
#         'Mathematics': {'nodes': {1723781, 1890514}, 'leafs': {}}}},
#       'Statistical physics': {'nodes': {138467},
#        'leafs': {'Magnetic moment': {'nodes': {322445}, 'leafs': {}}}},
#       'Materials science': {'nodes': {238173, 885498, 1037553},
#        'leafs': {'Machine learning': {'nodes': {141796}, 'leafs': {}},
#         'Absorption (acoustics)': {'nodes': {204019}, 'leafs': {}},
#         'Critical current': {'nodes': {687137}, 'leafs': {}}}},
#       'Ferromagnetism': {'nodes': {142154},
#        'leafs': {'Parity (physics)': {'nodes': {228558}, 'leafs': {}},
#         'Crystallography': {'nodes': {417326}, 'leafs': {}},
#         'Order (exchange)': {'nodes': {1485916}, 'leafs': {}},
#         'Paramagnetism': {'nodes': {1652530}, 'leafs': {}},
#         'Spectral line': {'nodes': {1853872}, 'leafs': {}}}},
#       'Lattice (music)': {'nodes': set(),
#        'leafs': {'Scanning tunneling microscope': {'nodes': {152424},
#          'leafs': {}},
#         'Ginzburg–Landau theory': {'nodes': {168953}, 'leafs': {}},
#         'High-temperature superconductivity': {'nodes': {506954}, 'leafs': {}},
#         'Magnetic field': {'nodes': {1289258}, 'leafs': {}},
#         'Acoustics': {'nodes': {1451331}, 'leafs': {}},
#         'Charge (physics)': {'nodes': {1654193}, 'leafs': {}},
#         'Crystallography': {'nodes': {1673600}, 'leafs': {}},
#         'Vortex state': {'nodes': {1754099}, 'leafs': {}}}},
#       'Superconducting transition temperature': {'nodes': set(),
#        'leafs': {'Sign (mathematics)': {'nodes': {165723}, 'leafs': {}},
#         'Transition temperature': {'nodes': {222037}, 'leafs': {}},
#         'Cuprate': {'nodes': {886660}, 'leafs': {}},
#         'Electrical resistivity and conductivity': {'nodes': {2027980},
#          'leafs': {}}}},
#       'Quantum critical point': {'nodes': set(),
#        'leafs': {'Magnetic field': {'nodes': {167671}, 'leafs': {}},
#         'Liquid crystal': {'nodes': {1442157}, 'leafs': {}}}},
#       'Perpendicular': {'nodes': set(),
#        'leafs': {'Layer (electronics)': {'nodes': {168025}, 'leafs': {}},
#         'Coupling (piping)': {'nodes': {1873993}, 'leafs': {}}}},
#       'X-ray absorption spectroscopy': {'nodes': set(),
#        'leafs': {'Charge (physics)': {'nodes': {192676}, 'leafs': {}}}},
#       'Coherence length': {'nodes': set(),
#        'leafs': {'Amplitude': {'nodes': {208599}, 'leafs': {}},
#         'Cooper pair': {'nodes': {1005378}, 'leafs': {}},
#         'Mean free path': {'nodes': {1043772}, 'leafs': {}},
#         'Energy (signal processing)': {'nodes': {1454555}, 'leafs': {}},
#         'Magnetization': {'nodes': {1966167}, 'leafs': {}}}},
#       'Phase (matter)': {'nodes': set(),
#        'leafs': {'Instability': {'nodes': {222538}, 'leafs': {}},
#         'Materials science': {'nodes': {502476}, 'leafs': {}},
#         'Current (fluid)': {'nodes': {747292}, 'leafs': {}},
#         'Topology (electrical circuits)': {'nodes': {1729144}, 'leafs': {}}}},
#       'Diamagnetism': {'nodes': set(),
#        'leafs': {'Magnetic susceptibility': {'nodes': {227963}, 'leafs': {}},
#         'Meissner effect': {'nodes': {540244}, 'leafs': {}},
#         'Anisotropy': {'nodes': {587958}, 'leafs': {}}}},
#       'Space (punctuation)': {'nodes': set(),
#        'leafs': {'Sulfide': {'nodes': {247780}, 'leafs': {}}}},
#       'Charge density wave': {'nodes': set(),
#        'leafs': {'Ginzburg–Landau theory': {'nodes': {254768}, 'leafs': {}},
#         'Spin density wave': {'nodes': {499915}, 'leafs': {}}}},
#       'Periodic boundary conditions': {'nodes': set(),
#        'leafs': {'Coulomb': {'nodes': {257956}, 'leafs': {}}}},
#       'Pairing': {'nodes': set(),
#        'leafs': {'Hubbard model': {'nodes': {262075, 408032, 1866776},
#          'leafs': {}},
#         'Quantum tunnelling': {'nodes': {509783}, 'leafs': {}},
#         'Quasiparticle': {'nodes': {515320}, 'leafs': {}},
# ...
#    'leafs': {'Oxygen': {'nodes': set(),
#      'leafs': {'Oxide': {'nodes': set(),
#        'leafs': {'Magnetic susceptibility': {'nodes': {1629970},
#          'leafs': {}}}}}}}},
#   'Embedding': {'nodes': set(),
#    'leafs': {'Heterojunction': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Computation': {'nodes': {1639116}, 'leafs': {}}}}}}}},
#   'Commensurability (mathematics)': {'nodes': set(),
#    'leafs': {'Vortex': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Pinning force': {'nodes': {1639121}, 'leafs': {}}}}}}}},
#   'Similarity (geometry)': {'nodes': set(),
#    'leafs': {'Phonon': {'nodes': set(),
#      'leafs': {'Basis (linear algebra)': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1640458}, 'leafs': {}}}}}}}},
#   'Semimetal': {'nodes': set(),
#    'leafs': {'Anisotropy': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Topology (electrical circuits)': {'nodes': {1640466},
#          'leafs': {}}}}}},
#     'Paramagnetism': {'nodes': set(),
#      'leafs': {'Dirac (video compression format)': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1793525},
#          'leafs': {}}}}}},
#     'Condensed matter physics': {'nodes': set(),
#      'leafs': {'Magnetism': {'nodes': set(),
#        'leafs': {'Tungsten': {'nodes': {1843336}, 'leafs': {}}}},
#       'Lattice (music)': {'nodes': set(),
#        'leafs': {'Dispersion (optics)': {'nodes': {1881259}, 'leafs': {}}}}}},
#     'Weyl semimetal': {'nodes': set(),
#      'leafs': {'Tetragonal crystal system': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1904955},
#          'leafs': {}}}}}}}},
#   'Spintronics': {'nodes': set(),
#    'leafs': {'Quasiparticle': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Spin (aerodynamics)': {'nodes': {1662061}, 'leafs': {}}}}}},
#     'Electronic band': {'nodes': set(),
#      'leafs': {'Materials science': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1852005},
#          'leafs': {}}}}}},
#     'Spin (aerodynamics)': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1939600}, 'leafs': {}}}}}}}},
#   'X-ray crystallography': {'nodes': set(),
#    'leafs': {'Analytical Chemistry (journal)': {'nodes': set(),
#      'leafs': {'Phase (matter)': {'nodes': set(),
#        'leafs': {'Diffraction': {'nodes': {1662930}, 'leafs': {}}}}}}}},
#   'Hyperfine structure': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Crystallography': {'nodes': {1676540}, 'leafs': {}}}}}}}},
#   'Dimer': {'nodes': set(),
#    'leafs': {'Crystallography': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Electrical resistivity and conductivity': {'nodes': {1683872},
#          'leafs': {}}}}}}}},
#   'Argon': {'nodes': set(),
#    'leafs': {'Materials science': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Crystal structure': {'nodes': {1690377}, 'leafs': {}}}}}}}},
#   'Node (physics)': {'nodes': set(),
#    'leafs': {'Quantum tunnelling': {'nodes': set(),
#      'leafs': {'Order (exchange)': {'nodes': set(),
#        'leafs': {'Magnetic field': {'nodes': {1691077}, 'leafs': {}}}}}}}},
#   'Proton': {'nodes': set(),
#    'leafs': {'Electrical resistivity and conductivity': {'nodes': set(),
#      'leafs': {'Scattering': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1696239}, 'leafs': {}}}}}}}},
#   'Honeycomb': {'nodes': set(),
#    'leafs': {'Charge (physics)': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Charge ordering': {'nodes': {1708146}, 'leafs': {}}}}}},
#     'Point reflection': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Electrical resistivity and conductivity': {'nodes': {1967720},
#          'leafs': {}}}}}}}},
#   'Coplanar waveguide': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': set(),
#      'leafs': {'Permittivity': {'nodes': set(),
#        'leafs': {'Dielectric': {'nodes': {1724399}, 'leafs': {}}}}}}}},
#   'Monatomic ion': {'nodes': set(),
#    'leafs': {'Cuprate': {'nodes': set(),
#      'leafs': {'Chemistry': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1729706},
#          'leafs': {}}}}}}}},
#   'Cobalt': {'nodes': set(),
#    'leafs': {'Materials science': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Carbide': {'nodes': {1729757}, 'leafs': {}}}}}}}},
#   'Technetium': {'nodes': set(),
#    'leafs': {'Crystal structure': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Materials science': {'nodes': {1734058}, 'leafs': {}}}}}}}},
#   'Coupling constant': {'nodes': set(),
#    'leafs': {'Phonon': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Electron': {'nodes': {1739814}, 'leafs': {}}}}}}}},
#   'Floquet theory': {'nodes': set(),
#    'leafs': {'Cuprate': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Topology (electrical circuits)': {'nodes': {1748328},
#          'leafs': {}}}}}}}},
#   'Thermal diffusivity': {'nodes': set(),
#    'leafs': {'Materials science': {'nodes': set(),
#      'leafs': {'Photon': {'nodes': set(),
#        'leafs': {'Biasing': {'nodes': {1752117}, 'leafs': {}}}}}}}},
#   'Chirality (physics)': {'nodes': set(),
#    'leafs': {'Supercurrent': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1755276}, 'leafs': {}}}}}}}},
#   'Phosphorene': {'nodes': set(),
#    'leafs': {'Intercalation (chemistry)': {'nodes': set(),
#      'leafs': {'Orthorhombic crystal system': {'nodes': set(),
#        'leafs': {'Alkali metal': {'nodes': {1756224}, 'leafs': {}}}}}}}},
#   'Cathode ray': {'nodes': set(),
#    'leafs': {'Instability': {'nodes': set(),
#      'leafs': {'Particle accelerator': {'nodes': set(),
#        'leafs': {'Beam (structure)': {'nodes': {1759344}, 'leafs': {}}}}}}}},
#   'Surface roughness': {'nodes': set(),
#    'leafs': {'Surface finish': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Inversion (geology)': {'nodes': {1764931},
#          'leafs': {}}}}}}}},
#   'Duality (order theory)': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Phase transition': {'nodes': {1775872}, 'leafs': {}}}}}}}},
#   'Kinetic inductance': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': set(),
#      'leafs': {'Dissipation': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1776234}, 'leafs': {}}}}}}}},
#   'Bromine': {'nodes': set(),
#    'leafs': {'Halogen': {'nodes': set(),
#      'leafs': {'Ab initio': {'nodes': set(),
#        'leafs': {'Materials science': {'nodes': {1786585}, 'leafs': {}}}}}}}},
#   'Pyrite': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': set(),
#      'leafs': {'Materials science': {'nodes': set(),
#        'leafs': {'Dimer': {'nodes': {1788018}, 'leafs': {}}}}}}}},
#   'Electronics': {'nodes': set(),
#    'leafs': {'Charge (physics)': {'nodes': set(),
#      'leafs': {'Transistor': {'nodes': set(),
#        'leafs': {'Coupling (piping)': {'nodes': {1792521}, 'leafs': {}}}}}}}},
#   'Polarization (electrochemistry)': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': set(),
#      'leafs': {'Excitation': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1801046},
#          'leafs': {}}}}}}}},
#   'Milestone': {'nodes': set(),
#    'leafs': {'Hydrogen sulfide': {'nodes': set(),
#      'leafs': {'Sulfide': {'nodes': set(),
#        'leafs': {'Hydrogen': {'nodes': {1801379}, 'leafs': {}}}}}}}},
#   'Renormalization group': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Ab initio': {'nodes': {1809003}, 'leafs': {}}}}}}}},
#   'Flux method': {'nodes': set(),
#    'leafs': {'Ferromagnetism': {'nodes': set(),
#      'leafs': {'Magnetization': {'nodes': set(),
#        'leafs': {'Single crystal': {'nodes': {1819769}, 'leafs': {}}}}}}}},
#   'Sulfide': {'nodes': set(),
#    'leafs': {'Materials science': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1820439}, 'leafs': {}}}}}}}},
#   'Weyl semimetal': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': set(),
#      'leafs': {'Semimetal': {'nodes': set(),
#        'leafs': {'MAJORANA': {'nodes': {1834247}, 'leafs': {}}}}}},
#     'Doping': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Semimetal': {'nodes': {1924074}, 'leafs': {}}}}}}}},
#   'Electronegativity': {'nodes': set(),
#    'leafs': {'Crystallography': {'nodes': set(),
#      'leafs': {'Covalent bond': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1840189}, 'leafs': {}}}}}}}},
#   'Spin–orbit interaction': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': set(),
#      'leafs': {'Coupling (piping)': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1857465},
#          'leafs': {}}}}}}}},
#   'Periodic table': {'nodes': set(),
#    'leafs': {'Deep learning': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Artificial intelligence': {'nodes': {1860670},
#          'leafs': {}}}}}}}},
#   'Energy landscape': {'nodes': set(),
#    'leafs': {'Energy (signal processing)': {'nodes': set(),
#      'leafs': {'Field (mathematics)': {'nodes': set(),
#        'leafs': {'Matching (statistics)': {'nodes': {1875319},
#          'leafs': {}}}}}}}},
#   'Unitary state': {'nodes': set(),
#    'leafs': {'Dirac (video compression format)': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Symmetry (geometry)': {'nodes': {1881298},
#          'leafs': {}}}}}}}},
#   'Bearing (navigation)': {'nodes': set(),
#    'leafs': {'Phenomenology (philosophy)': {'nodes': set(),
#      'leafs': {'Mechanical engineering': {'nodes': set(),
#        'leafs': {'Computer science': {'nodes': {1902102}, 'leafs': {}}}}}}}},
#   'Image warping': {'nodes': set(),
#    'leafs': {'Pairing': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1902472}, 'leafs': {}}}}}}}},
#   'Praseodymium': {'nodes': set(),
#    'leafs': {'Non-blocking I/O': {'nodes': set(),
#      'leafs': {'Materials science': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1913137},
#          'leafs': {}}}}}}}},
#   'Scalar field': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': set(),
#      'leafs': {'Holography': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {1924228}, 'leafs': {}}}}}}}},
#   'Samarium': {'nodes': set(),
#    'leafs': {'Electrical resistivity and conductivity': {'nodes': set(),
#      'leafs': {'Doping': {'nodes': set(),
#        'leafs': {'Activation energy': {'nodes': {1931814}, 'leafs': {}}}}}}}},
#   'Spin valve': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': set(),
#      'leafs': {'Spintronics': {'nodes': set(),
#        'leafs': {'Ferromagnetism': {'nodes': {1935338}, 'leafs': {}}}}}}}},
#   'Hexamethylenediamine': {'nodes': set(),
#    'leafs': {'Annealing (glass)': {'nodes': set(),
#      'leafs': {'Materials science': {'nodes': set(),
#        'leafs': {'Intercalation (chemistry)': {'nodes': {1937578},
#          'leafs': {}}}}}}}},
#   'Style (visual arts)': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Materials science': {'nodes': {1942608}, 'leafs': {}}}}}}}},
#   'Magnetic flux quantum': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': set(),
#      'leafs': {'Magnetic field': {'nodes': set(),
#        'leafs': {'Flux (metallurgy)': {'nodes': {1949548}, 'leafs': {}}}}}}}},
#   'Optoelectronics': {'nodes': set(),
#    'leafs': {'Antenna (radio)': {'nodes': set(),
#      'leafs': {'Voltage': {'nodes': set(),
#        'leafs': {'Magnetic field': {'nodes': {1950337}, 'leafs': {}}}}}}}},
#   'Refrigeration': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': set(),
#      'leafs': {'Materials science': {'nodes': set(),
#        'leafs': {'Electron': {'nodes': {1951160}, 'leafs': {}}}}}}}},
#   'Phenomenon': {'nodes': set(),
#    'leafs': {'Theoretical physics': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Natural (archaeology)': {'nodes': {1960542},
#          'leafs': {}}}}}},
#     'Pleasure': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Pairing': {'nodes': {2032469}, 'leafs': {}}}}}}}},
#   'Causality (physics)': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': set(),
#      'leafs': {'Metamaterial': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {1966173},
#          'leafs': {}}}}}}}},
#   'Parameter space': {'nodes': set(),
#    'leafs': {'Bifurcation': {'nodes': set(),
#      'leafs': {'Symmetry (geometry)': {'nodes': set(),
#        'leafs': {'Statistical physics': {'nodes': {1968608},
#          'leafs': {}}}}}}}},
#   'Oxidizing agent': {'nodes': set(),
#    'leafs': {'Annealing (glass)': {'nodes': set(),
#      'leafs': {'Materials science': {'nodes': set(),
#        'leafs': {'Chalcogenide': {'nodes': {1978206}, 'leafs': {}}}}}}}},
#   'Compendium': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': set(),
#      'leafs': {'High-temperature superconductivity': {'nodes': set(),
#        'leafs': {'Room-temperature superconductor': {'nodes': {1987499},
#          'leafs': {}}}}}}}},
#   'High entropy alloys': {'nodes': set(),
#    'leafs': {'Materials science': {'nodes': set(),
#      'leafs': {'Valence electron': {'nodes': set(),
#        'leafs': {'Atomic radius': {'nodes': {1993711}, 'leafs': {}}}}}}}},
#   'Phosphide': {'nodes': set(),
#    'leafs': {'Lattice constant': {'nodes': set(),
#      'leafs': {'Coupling constant': {'nodes': set(),
#        'leafs': {'Stoichiometry': {'nodes': {1994659}, 'leafs': {}}}}}},
#     'Condensed matter physics': {'nodes': set(),
#      'leafs': {'Materials science': {'nodes': set(),
#        'leafs': {'Electrical resistivity and conductivity': {'nodes': {2010671},
#          'leafs': {}}}}}}}},
#   'Triclinic crystal system': {'nodes': set(),
#    'leafs': {'Arsenide': {'nodes': set(),
#      'leafs': {'Materials science': {'nodes': set(),
#        'leafs': {'Platinum': {'nodes': {1996700}, 'leafs': {}}}}}}}},
#   'Cage': {'nodes': set(),
#    'leafs': {'Materials science': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Physics': {'nodes': {2009947}, 'leafs': {}}}}}}}},
#   'Circulator': {'nodes': set(),
#    'leafs': {'Condensed matter physics': {'nodes': set(),
#      'leafs': {'Magnetic field': {'nodes': set(),
#        'leafs': {'Phase (matter)': {'nodes': {2013075}, 'leafs': {}}}}}}}},
#   'Muon': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': set(),
#      'leafs': {'Relaxation (psychology)': {'nodes': set(),
#        'leafs': {'Coupling (piping)': {'nodes': {2025351}, 'leafs': {}}}}}}}},
#   'Library science': {'nodes': set(),
#    'leafs': {'Engineering physics': {'nodes': set(),
#      'leafs': {'Physics': {'nodes': set(),
#        'leafs': {'Engineering ethics': {'nodes': {2030949}, 'leafs': {}}}}}}}},
#   'BETA (programming language)': {'nodes': set(),
#    'leafs': {'Physics': {'nodes': set(),
#      'leafs': {'Condensed matter physics': {'nodes': set(),
#        'leafs': {'Materials science': {'nodes': {2036214}, 'leafs': {}}}}}}}},
#   'Oxonium ion': {'nodes': set(),
#    'leafs': {'Phase diagram': {'nodes': set(),
#      'leafs': {'Ion': {'nodes': set(),
#        'leafs': {'Condensed matter physics': {'nodes': {2046498},
#          'leafs': {}}}}}}}}}}

# %%
tree = {}
tree = fill_tree(tree, frozenset(['phase transitions']), 4)
for i in range(3):
    tree = fill_tree(tree, frozenset(['phase transitions', 'x-ray']), i+1) #["phase transitions"]

# %%
tree = fill_tree(tree, frozenset(['phase transitions', 'x-ray', 'balinha juquinha']), 5)

# %%
tree = fill_tree(tree, frozenset(['phase transitions', 'x-ray', 'maca verde gostosinha']), 6)

# %%
tree = fill_tree(tree, frozenset(['phase transitions']), 12)

# %%
tree.keys()
# Out:
# dict_keys([frozenset({'phase transitions'}), frozenset({'x-ray'}), frozenset({'balinha juquinha'}), frozenset({'maca verde gostosinha'})])

# %%
tree
# Out:
# {frozenset({'phase transitions'}): {'nodes': {4, 12},
#   'leafs': {frozenset({'x-ray'}): {'nodes': {1, 2, 3},
#     'leafs': {frozenset({'balinha juquinha'}): {'nodes': {5}, 'leafs': {}},
#      frozenset({'maca verde gostosinha'}): {'nodes': {6}, 'leafs': {}}}},
#    frozenset({'balinha juquinha'}): {'nodes': set(),
#     'leafs': {frozenset({'x-ray'}): {'nodes': {5}, 'leafs': {}}}},
#    frozenset({'maca verde gostosinha'}): {'nodes': set(),
#     'leafs': {frozenset({'x-ray'}): {'nodes': {6}, 'leafs': {}}}}}},
#  frozenset({'x-ray'}): {'nodes': set(),
#   'leafs': {frozenset({'phase transitions'}): {'nodes': {1, 2, 3},
#     'leafs': {frozenset({'balinha juquinha'}): {'nodes': {5}, 'leafs': {}},
#      frozenset({'maca verde gostosinha'}): {'nodes': {6}, 'leafs': {}}}},
#    frozenset({'balinha juquinha'}): {'nodes': set(),
#     'leafs': {frozenset({'phase transitions'}): {'nodes': {5}, 'leafs': {}}}},
#    frozenset({'maca verde gostosinha'}): {'nodes': set(),
#     'leafs': {frozenset({'phase transitions'}): {'nodes': {6},
#       'leafs': {}}}}}},
#  frozenset({'balinha juquinha'}): {'nodes': set(),
#   'leafs': {frozenset({'phase transitions'}): {'nodes': set(),
#     'leafs': {frozenset({'x-ray'}): {'nodes': {5}, 'leafs': {}}}},
#    frozenset({'x-ray'}): {'nodes': set(),
#     'leafs': {frozenset({'phase transitions'}): {'nodes': {5},
#       'leafs': {}}}}}},
#  frozenset({'maca verde gostosinha'}): {'nodes': set(),
#   'leafs': {frozenset({'phase transitions'}): {'nodes': set(),
#     'leafs': {frozenset({'x-ray'}): {'nodes': {6}, 'leafs': {}}}},
#    frozenset({'x-ray'}): {'nodes': set(),
#     'leafs': {frozenset({'phase transitions'}): {'nodes': {6},
#       'leafs': {}}}}}}}

# %%
tree = fill_tree(tree, frozenset(['x-ray']), 8)

# %%
tree = fill_tree(tree, frozenset(['phase transitions', 'x-ray']), 10) #["phase transitions"]

# %%
tree[frozenset(["phase transitions"])] #["leafs"]
# Out:
# {'nodes': {4, 12},
#  'leafs': {frozenset({'x-ray'}): {'nodes': {1, 2, 3, 10},
#    'leafs': {frozenset({'balinha juquinha'}): {'nodes': {5}, 'leafs': {}},
#     frozenset({'maca verde gostosinha'}): {'nodes': {6}, 'leafs': {}}}},
#   frozenset({'balinha juquinha'}): {'nodes': set(),
#    'leafs': {frozenset({'x-ray'}): {'nodes': {5}, 'leafs': {}}}},
#   frozenset({'maca verde gostosinha'}): {'nodes': set(),
#    'leafs': {frozenset({'x-ray'}): {'nodes': {6}, 'leafs': {}}}}}}

# %%
tree
# Out:
# {frozenset({'phase transitions'}): {'nodes': {4, 12},
#   'leafs': {frozenset({'x-ray'}): {'nodes': {1, 2, 3, 10},
#     'leafs': {frozenset({'balinha juquinha'}): {'nodes': {5}, 'leafs': {}},
#      frozenset({'maca verde gostosinha'}): {'nodes': {6}, 'leafs': {}}}},
#    frozenset({'balinha juquinha'}): {'nodes': set(),
#     'leafs': {frozenset({'x-ray'}): {'nodes': {5}, 'leafs': {}}}},
#    frozenset({'maca verde gostosinha'}): {'nodes': set(),
#     'leafs': {frozenset({'x-ray'}): {'nodes': {6}, 'leafs': {}}}}}},
#  frozenset({'x-ray'}): {'nodes': {8},
#   'leafs': {frozenset({'phase transitions'}): {'nodes': {1, 2, 3, 10},
#     'leafs': {frozenset({'balinha juquinha'}): {'nodes': {5}, 'leafs': {}},
#      frozenset({'maca verde gostosinha'}): {'nodes': {6}, 'leafs': {}}}},
#    frozenset({'balinha juquinha'}): {'nodes': set(),
#     'leafs': {frozenset({'phase transitions'}): {'nodes': {5}, 'leafs': {}}}},
#    frozenset({'maca verde gostosinha'}): {'nodes': set(),
#     'leafs': {frozenset({'phase transitions'}): {'nodes': {6},
#       'leafs': {}}}}}},
#  frozenset({'balinha juquinha'}): {'nodes': set(),
#   'leafs': {frozenset({'phase transitions'}): {'nodes': set(),
#     'leafs': {frozenset({'x-ray'}): {'nodes': {5}, 'leafs': {}}}},
#    frozenset({'x-ray'}): {'nodes': set(),
#     'leafs': {frozenset({'phase transitions'}): {'nodes': {5},
#       'leafs': {}}}}}},
#  frozenset({'maca verde gostosinha'}): {'nodes': set(),
#   'leafs': {frozenset({'phase transitions'}): {'nodes': set(),
#     'leafs': {frozenset({'x-ray'}): {'nodes': {6}, 'leafs': {}}}},
#    frozenset({'x-ray'}): {'nodes': set(),
#     'leafs': {frozenset({'phase transitions'}): {'nodes': {6},
#       'leafs': {}}}}}}}

# %%
def construct_hierarchy_tree_of_communities(nodes_communities, fill_empty="no_keyword_attributed"):
    tree = {}
    current_keys = []
    
    def dfs_search_tree(tree, criteria_fn, access_path=[]):
        if len(list(tree.keys())) == 0:
            
        if criteria_fn()
    
    for i, c_curr in enumerate(tqdm(nodes_communities, total=len(nodes_communities))):
        #k_curr = set(eval(row["keywords"]))
        if len(c_curr) == 0:
            c_curr = {fill_empty}

        
    
        for j, k in enumerate(current_keys):
            s_sorted_keys = str(sorted(list(k_curr)))
            s_sorted_keys_old = str(sorted(list(k)))
            if len(k - k_curr) == 0:
                if len(k_curr) > len(k):
                    current_keys[j] = k_curr
                    oa_keyword_communities_agg[s_sorted_keys] = oa_keyword_communities_agg[s_sorted_keys_old] | {i}
                    del oa_keyword_communities_agg[s_sorted_keys_old]
                else:
                    oa_keyword_communities_agg[s_sorted_keys_old] = oa_keyword_communities_agg[s_sorted_keys_old] | {i}
        
        if len(ks) > 0:
            first_row_key = ks[0]
        else:
            first_row_key = "no_keyword_attributed"
        
        if first_row_key not in open_alex_keyword_communities_first_kw:
            open_alex_keyword_communities_first_kw[first_row_key] = {i}
        else:
            open_alex_keyword_communities_first_kw[first_row_key] = open_alex_keyword_communities_first_kw[first_row_key] | {i}

# %%
oa_keyword_communities_tree = {}
current_keys = []
for i, row in df.iterrows():
    k_curr = set(eval(row["keywords"]))
    if len(k_curr) == 0:
        k_curr = {no_keyword_attributed}

    for j, k in enumerate(current_keys):
        s_sorted_keys = str(sorted(list(k_curr)))
        s_sorted_keys_old = str(sorted(list(k)))
        if len(k - k_curr) == 0:
            if len(k_curr) > len(k):
                current_keys[j] = k_curr
                oa_keyword_communities_agg[s_sorted_keys] = oa_keyword_communities_agg[s_sorted_keys_old] | {i}
                del oa_keyword_communities_agg[s_sorted_keys_old]
            else:
                oa_keyword_communities_agg[s_sorted_keys_old] = oa_keyword_communities_agg[s_sorted_keys_old] | {i}
    
    if len(ks) > 0:
        first_row_key = ks[0]
    else:
        first_row_key = "no_keyword_attributed"
    
    if first_row_key not in open_alex_keyword_communities_first_kw:
        open_alex_keyword_communities_first_kw[first_row_key] = {i}
    else:
        open_alex_keyword_communities_first_kw[first_row_key] = open_alex_keyword_communities_first_kw[first_row_key] | {i}

# %%
df
# Out:
#                                        id  \
# 0         https://openalex.org/W100001730
# 1        https://openalex.org/W1000042173
# 2         https://openalex.org/W100006313
# 3        https://openalex.org/W1000096099
# 4        https://openalex.org/W1000312985
# ...                                   ...
# 2048702   https://openalex.org/W999422512
# 2048703   https://openalex.org/W999575332
# 2048704    https://openalex.org/W99994197
# 2048705   https://openalex.org/W999961912
# 2048706   https://openalex.org/W999972508
#
#                                                   abstract  \
# 0        the raman spectra of the parent compound naxco...
# 1        publisher summary this chapter discusses the s...
# 2        in a wire spark-chamber experiment the squared...
# 3        using angle-resolved photoemission, we have ma...
# 4        we demonstrate controlled manipulation of larg...
# ...                                                    ...
# 2048702  a mostly single bcc phase with nanoscale grain...
# 2048703  publisher summary this chapter discusses a phe...
# 2048704  measurements are reported of the transmission ...
# 2048705  this chapter reviews the computational methods...
# 2048706  the distributions of major and minor elements ...
#
#                                                      title publication_date  \
# 0        raman spectroscopy study ofnaxcoo2and supercon...       2004-08-10
# 1            chapter 1: vortices in rotating superfluid3he       1986-01-01
# 2        experimental study on the τ± decay matrix element       1972-03-01
# 3         fermi surface and electronic structure ofnd2−xce       1993-05-17
# 4         microparticle manipulation using inertial forces       2006-02-27
# ...                                                    ...              ...
# 2048702  high saturation magnetization and soft magneti...       1991-01-01
# 2048703  chapter 1 protein-lipid interactions and membr...       1993-01-01
# 2048704             infrared optical excitations inla2nio4       1995-10-01
# 2048705  energies and asymptotic analysis for helium ry...       1993-01-01
# 2048706  high pressure metal–silicate partitioning of n...       2015-10-01
#
#                                                   keywords  \
# 0             ['raman spectroscopy', 'spectroscopy study']
# 1                            ['superfluid3he', 'vortices']
# 2                                               ['matrix']
# 3                ['fermi surface', 'electronic structure']
# 4                               ['forces', 'manipulation']
# ...                                                    ...
# 2048702  ['soft magnetic properties', 'high saturation ...
# 2048703        ['membrane heterogeneity', 'protein-lipid']
# 2048704                   ['infrared optical excitations']
# 2048705                            ['asymptotic analysis']
# 2048706   ['high pressure metal–silicate', 'partitioning']
#
#                                                   concepts
# 0        [('Raman spectroscopy', 0.89063823), ('Superco...
# 1        [('Vortex', 0.7865634), ('Physics', 0.376391),...
# 2        [('Physics', 0.9268166), ('Matrix element', 0....
# 3        [('Fermi surface', 0.59463906), ('Physics', 0....
# 4        [('Particle (ecology)', 0.62976944), ('Micropa...
# ...                                                    ...
# 2048702  [('Materials science', 0.725253), ('Amorphous ...
# 2048703  [('Chemistry', 0.4417297), ('Biology', 0.38962...
# 2048704  [('Physics', 0.62062633), ('Absorption (acoust...
# 2048705  [('Physics', 0.88181573), ('Rydberg formula', ...
# 2048706  [('Silicate', 0.79294956), ('Mantle (geology)'...
#
# [2048707 rows x 6 columns]
